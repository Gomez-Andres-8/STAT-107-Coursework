# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: DataFrame of Your NWS Weather Forecast</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/dataframe-nws-weather-forecast/">https://discovery.cs.illinois.edu/microproject/dataframe-nws-weather-forecast/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Data API: National Weather Service (NWS) Weather Forecast
#
# The National Weather Service allows, for free, "developers access to critical forecasts, alerts, and observations, along with other weather data."  You can find the full documentation of their API at: [https://www.weather.gov/documentation/services-web-api](https://www.weather.gov/documentation/services-web-api).
#
# Since weather data is based on your location, you need to find the latitude and longitude of coordinate of your location!
#
# - One quick way to do this is to pull up [Google Maps](https://maps.google.com/) and **right click** on a location.
# - The first option will be the `latitude, longitude` of the location of your click on the map.  You can click it to copy it to your clipboard!
#
# Once you have your location, add each component to a variable below:

# %%
latitude = 40.12819860276954
longitude = -88.22246231722355

# %% [markdown]
# ### Finding Your Forecast Area
#
# The National Weather Service API provides a `/points/` endpoint that uses the `latitude,longitude` value to return a weather forecast.  The full URL for this endpoint is in the following format:
#
# ```
# https://api.weather.gov/points/LATITUDE,LONGITUDE
# ```
#
# This endpoint also returns a JSON instead of a CSV.  Here's q uick summary of loading a JSON instead of a CSV:
#
# - Using pandas, use `pd.read_json` to read a JSON (including this JSON that includes the weather in your location).
# - Make sure to replace `LATITUDE` and `LONGITUDE` in the URL with your actual latitude and longitude.
# - This JSON is organized as a **series**.  As a parameter to `read_json`, make sure to include `typ="series"`.
# - For example: `pd.read_json(..., typ="series")`.
#
# Store the result in a variable named `pointsJSON`:

# %%
import pandas as pd
pointsJSON = pd.read_json("https://api.weather.gov/points/40.12819860276954,-88.22246231722355" , typ="series")
pointsJSON
# Out:
# @context      [https://geojson.org/geojson-ld/geojson-contex...
# id              https://api.weather.gov/points/40.1282,-88.2225
# type                                                    Feature
# geometry      {'type': 'Point', 'coordinates': [-88.2225, 40...
# properties    {'@id': 'https://api.weather.gov/points/40.128...
# dtype: object

# %% [markdown]
# ### Finding Your Forecast URL
#
# The JSON you just loaded has multiple fields including two fields with data:
#
# - `geometry`, which include the geometric area for the result (you supplied a single point, but weather forecasts are given for areas that can be many square miles)
# - `properties`, which includes all properties about the location you requested
#
# You can inspect the data further by running `pointsJSON["geometry"]` or `pointsJSON["properties"]`.  Inspect the **properties** and look for the URL that provides the **hourly forecast**.

# %%
pointsJSON["properties"]
# Out:
# {'@id': 'https://api.weather.gov/points/40.1282,-88.2225',
#  '@type': 'wx:Point',
#  'cwa': 'ILX',
#  'forecastOffice': 'https://api.weather.gov/offices/ILX',
#  'gridId': 'ILX',
#  'gridX': 95,
#  'gridY': 72,
#  'forecast': 'https://api.weather.gov/gridpoints/ILX/95,72/forecast',
#  'forecastHourly': 'https://api.weather.gov/gridpoints/ILX/95,72/forecast/hourly',
#  'forecastGridData': 'https://api.weather.gov/gridpoints/ILX/95,72',
#  'observationStations': 'https://api.weather.gov/gridpoints/ILX/95,72/stations',
#  'relativeLocation': {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-88.197323, 40.110126]},
#   'properties': {'city': 'Urbana',
#    'state': 'IL',
#    'distance': {'unitCode': 'wmoUnit:m', 'value': 2936.3661917612},
#    'bearing': {'unitCode': 'wmoUnit:degree_(angle)', 'value': 313}}},
#  'forecastZone': 'https://api.weather.gov/zones/forecast/ILZ045',
#  'county': 'https://api.weather.gov/zones/county/ILC019',
#  'fireWeatherZone': 'https://api.weather.gov/zones/fire/ILZ045',
#  'timeZone': 'America/Chicago',
#  'radarStation': 'KILX'}

# %% [markdown]
# ### Record Your Forecast URL
#
# Finally, record the URL that you can use to find the hourly forecast for your location:

# %%
hourlyForecastURL = "https://api.weather.gov/gridpoints/ILX/95,72/forecast/hourly"
hourlyForecastURL
# Out:
# 'https://api.weather.gov/gridpoints/ILX/95,72/forecast/hourly'

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Loading Your Weather Forecast as a DataFrame
#
# In the same way as you did in the beginning of this MicroProject, use the hourlyForecastURL and `pd.read_json` to load the your weather forecast.  Store your result in the variable `forecastJSON`:

# %%
forecastJSON = pd.read_json(hourlyForecastURL, typ="series")
forecastJSON
# Out:
# @context      [https://geojson.org/geojson-ld/geojson-contex...
# type                                                    Feature
# geometry      {'type': 'Polygon', 'coordinates': [[[-88.2461...
# properties    {'updated': '2023-03-03T19:25:29+00:00', 'unit...
# dtype: object

# %% [markdown]
# ### Finding the Forecast Data
#
# Inside of the `properties` data within `forecastJSON`, the `periods` data provides a **well-defined, structured** set of data that contains the forecast for every hour for your location.
#
# Check out how it looks in the raw form:

# %%
forecastJSON
# Out:
# @context      [https://geojson.org/geojson-ld/geojson-contex...
# type                                                    Feature
# geometry      {'type': 'Polygon', 'coordinates': [[[-88.2461...
# properties    {'updated': '2023-03-03T19:25:29+00:00', 'unit...
# dtype: object

# %% [markdown]
# Going deeper, the `properties` key has data related to the hourly forecast.  To view that, we can view `forecastJSON["properties"]`:

# %%
forecastJSON["properties"]
# Out:
# {'updated': '2023-03-03T19:25:29+00:00',
#  'units': 'us',
#  'forecastGenerator': 'HourlyForecastGenerator',
#  'generatedAt': '2023-03-03T21:06:04+00:00',
#  'updateTime': '2023-03-03T19:25:29+00:00',
#  'validTimes': '2023-03-03T13:00:00+00:00/P7DT12H',
#  'elevation': {'unitCode': 'wmoUnit:m', 'value': 224.028},
#  'periods': [{'number': 1,
#    'name': '',
#    'startTime': '2023-03-03T15:00:00-06:00',
#    'endTime': '2023-03-03T16:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 94},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#    'windSpeed': '32 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,94?size=small',
#    'shortForecast': 'Light Snow',
#    'detailedForecast': ''},
#   {'number': 2,
#    'name': '',
#    'startTime': '2023-03-03T16:00:00-06:00',
#    'endTime': '2023-03-03T17:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 87},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#    'windSpeed': '33 mph',
#    'windDirection': 'N',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,87?size=small',
#    'shortForecast': 'Light Snow',
#    'detailedForecast': ''},
#   {'number': 3,
#    'name': '',
#    'startTime': '2023-03-03T17:00:00-06:00',
#    'endTime': '2023-03-03T18:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '31 mph',
#    'windDirection': 'N',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,81?size=small',
#    'shortForecast': 'Heavy Snow',
#    'detailedForecast': ''},
#   {'number': 4,
#    'name': '',
#    'startTime': '2023-03-03T18:00:00-06:00',
#    'endTime': '2023-03-03T19:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 61},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '30 mph',
#    'windDirection': 'N',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,61?size=small',
#    'shortForecast': 'Rain And Snow Likely',
#    'detailedForecast': ''},
#   {'number': 5,
#    'name': '',
#    'startTime': '2023-03-03T19:00:00-06:00',
#    'endTime': '2023-03-03T20:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 35},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '29 mph',
#    'windDirection': 'NNW',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,35?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 6,
#    'name': '',
#    'startTime': '2023-03-03T20:00:00-06:00',
#    'endTime': '2023-03-03T21:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 21},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '26 mph',
#    'windDirection': 'NNW',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,21?size=small',
#    'shortForecast': 'Slight Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 7,
#    'name': '',
#    'startTime': '2023-03-03T21:00:00-06:00',
#    'endTime': '2023-03-03T22:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '24 mph',
#    'windDirection': 'NW',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,10?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 8,
#    'name': '',
#    'startTime': '2023-03-03T22:00:00-06:00',
#    'endTime': '2023-03-03T23:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 4},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '22 mph',
#    'windDirection': 'NW',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,4?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 9,
#    'name': '',
#    'startTime': '2023-03-03T23:00:00-06:00',
#    'endTime': '2023-03-04T00:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 33,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -0.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '17 mph',
#    'windDirection': 'NW',
#    'icon': 'https://api.weather.gov/icons/land/night/bkn,1?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 10,
#    'name': '',
#    'startTime': '2023-03-04T00:00:00-06:00',
#    'endTime': '2023-03-04T01:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '14 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 11,
#    'name': '',
#    'startTime': '2023-03-04T01:00:00-06:00',
#    'endTime': '2023-03-04T02:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 31,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '12 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 12,
#    'name': '',
#    'startTime': '2023-03-04T02:00:00-06:00',
#    'endTime': '2023-03-04T03:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 30,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '10 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 13,
#    'name': '',
#    'startTime': '2023-03-04T03:00:00-06:00',
#    'endTime': '2023-03-04T04:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 29,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.222222222222222},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '9 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 14,
#    'name': '',
#    'startTime': '2023-03-04T04:00:00-06:00',
#    'endTime': '2023-03-04T05:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 29,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.222222222222222},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '8 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 15,
#    'name': '',
#    'startTime': '2023-03-04T05:00:00-06:00',
#    'endTime': '2023-03-04T06:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 28,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '7 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 16,
#    'name': '',
#    'startTime': '2023-03-04T06:00:00-06:00',
#    'endTime': '2023-03-04T07:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 28,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '7 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,1?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 17,
#    'name': '',
#    'startTime': '2023-03-04T07:00:00-06:00',
#    'endTime': '2023-03-04T08:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 30,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '6 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,1?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 18,
#    'name': '',
#    'startTime': '2023-03-04T08:00:00-06:00',
#    'endTime': '2023-03-04T09:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '5 mph',
#    'windDirection': 'WSW',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 19,
#    'name': '',
#    'startTime': '2023-03-04T09:00:00-06:00',
#    'endTime': '2023-03-04T10:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '5 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 20,
#    'name': '',
#    'startTime': '2023-03-04T10:00:00-06:00',
#    'endTime': '2023-03-04T11:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 37,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '6 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,1?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 21,
#    'name': '',
#    'startTime': '2023-03-04T11:00:00-06:00',
#    'endTime': '2023-03-04T12:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 85},
#    'windSpeed': '6 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,1?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 22,
#    'name': '',
#    'startTime': '2023-03-04T12:00:00-06:00',
#    'endTime': '2023-03-04T13:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 42,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#    'windSpeed': '7 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 23,
#    'name': '',
#    'startTime': '2023-03-04T13:00:00-06:00',
#    'endTime': '2023-03-04T14:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 43,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#    'windSpeed': '8 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 24,
#    'name': '',
#    'startTime': '2023-03-04T14:00:00-06:00',
#    'endTime': '2023-03-04T15:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 45,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#    'windSpeed': '9 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 25,
#    'name': '',
#    'startTime': '2023-03-04T15:00:00-06:00',
#    'endTime': '2023-03-04T16:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 46,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 76},
#    'windSpeed': '9 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 26,
#    'name': '',
#    'startTime': '2023-03-04T16:00:00-06:00',
#    'endTime': '2023-03-04T17:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 45,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#    'windSpeed': '9 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 27,
#    'name': '',
#    'startTime': '2023-03-04T17:00:00-06:00',
#    'endTime': '2023-03-04T18:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 44,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#    'windSpeed': '8 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 28,
#    'name': '',
#    'startTime': '2023-03-04T18:00:00-06:00',
#    'endTime': '2023-03-04T19:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 43,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#    'windSpeed': '8 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 29,
#    'name': '',
#    'startTime': '2023-03-04T19:00:00-06:00',
#    'endTime': '2023-03-04T20:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 42,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '7 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 30,
#    'name': '',
#    'startTime': '2023-03-04T20:00:00-06:00',
#    'endTime': '2023-03-04T21:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 41,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '7 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 31,
#    'name': '',
#    'startTime': '2023-03-04T21:00:00-06:00',
#    'endTime': '2023-03-04T22:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 40,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '7 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 32,
#    'name': '',
#    'startTime': '2023-03-04T22:00:00-06:00',
#    'endTime': '2023-03-04T23:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '7 mph',
#    'windDirection': 'WSW',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 33,
#    'name': '',
#    'startTime': '2023-03-04T23:00:00-06:00',
#    'endTime': '2023-03-05T00:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '6 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 34,
#    'name': '',
#    'startTime': '2023-03-05T00:00:00-06:00',
#    'endTime': '2023-03-05T01:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 38,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.222222222222222},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '5 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#    'shortForecast': 'Mostly Clear',
#    'detailedForecast': ''},
#   {'number': 35,
#    'name': '',
#    'startTime': '2023-03-05T01:00:00-06:00',
#    'endTime': '2023-03-05T02:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 37,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '5 mph',
#    'windDirection': 'NW',
#    'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#    'shortForecast': 'Mostly Clear',
#    'detailedForecast': ''},
#   {'number': 36,
#    'name': '',
#    'startTime': '2023-03-05T02:00:00-06:00',
#    'endTime': '2023-03-05T03:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 36,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '5 mph',
#    'windDirection': 'N',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 37,
#    'name': '',
#    'startTime': '2023-03-05T03:00:00-06:00',
#    'endTime': '2023-03-05T04:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '5 mph',
#    'windDirection': 'N',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 38,
#    'name': '',
#    'startTime': '2023-03-05T04:00:00-06:00',
#    'endTime': '2023-03-05T05:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '5 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 39,
#    'name': '',
#    'startTime': '2023-03-05T05:00:00-06:00',
#    'endTime': '2023-03-05T06:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#    'windSpeed': '5 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 40,
#    'name': '',
#    'startTime': '2023-03-05T06:00:00-06:00',
#    'endTime': '2023-03-05T07:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#    'windSpeed': '6 mph',
#    'windDirection': 'ENE',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 41,
#    'name': '',
#    'startTime': '2023-03-05T07:00:00-06:00',
#    'endTime': '2023-03-05T08:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#    'windSpeed': '7 mph',
#    'windDirection': 'ENE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 42,
#    'name': '',
#    'startTime': '2023-03-05T08:00:00-06:00',
#    'endTime': '2023-03-05T09:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 36,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#    'windSpeed': '7 mph',
#    'windDirection': 'E',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 43,
#    'name': '',
#    'startTime': '2023-03-05T09:00:00-06:00',
#    'endTime': '2023-03-05T10:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#    'windSpeed': '8 mph',
#    'windDirection': 'E',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 44,
#    'name': '',
#    'startTime': '2023-03-05T10:00:00-06:00',
#    'endTime': '2023-03-05T11:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 42,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '9 mph',
#    'windDirection': 'ESE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 45,
#    'name': '',
#    'startTime': '2023-03-05T11:00:00-06:00',
#    'endTime': '2023-03-05T12:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 46,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#    'windSpeed': '10 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 46,
#    'name': '',
#    'startTime': '2023-03-05T12:00:00-06:00',
#    'endTime': '2023-03-05T13:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 49,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '12 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/day/ovc,0?size=small',
#    'shortForecast': 'Cloudy',
#    'detailedForecast': ''},
#   {'number': 47,
#    'name': '',
#    'startTime': '2023-03-05T13:00:00-06:00',
#    'endTime': '2023-03-05T14:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 52,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#    'windSpeed': '13 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 48,
#    'name': '',
#    'startTime': '2023-03-05T14:00:00-06:00',
#    'endTime': '2023-03-05T15:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 53,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#    'windSpeed': '13 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 49,
#    'name': '',
#    'startTime': '2023-03-05T15:00:00-06:00',
#    'endTime': '2023-03-05T16:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 54,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#    'windSpeed': '14 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 50,
#    'name': '',
#    'startTime': '2023-03-05T16:00:00-06:00',
#    'endTime': '2023-03-05T17:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 53,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#    'windSpeed': '15 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 51,
#    'name': '',
#    'startTime': '2023-03-05T17:00:00-06:00',
#    'endTime': '2023-03-05T18:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 52,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#    'windSpeed': '17 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 52,
#    'name': '',
#    'startTime': '2023-03-05T18:00:00-06:00',
#    'endTime': '2023-03-05T19:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 50,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '18 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/night/bkn,3?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 53,
#    'name': '',
#    'startTime': '2023-03-05T19:00:00-06:00',
#    'endTime': '2023-03-05T20:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 49,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '20 mph',
#    'windDirection': 'SE',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 54,
#    'name': '',
#    'startTime': '2023-03-05T20:00:00-06:00',
#    'endTime': '2023-03-05T21:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '21 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 55,
#    'name': '',
#    'startTime': '2023-03-05T21:00:00-06:00',
#    'endTime': '2023-03-05T22:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#    'windSpeed': '22 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 56,
#    'name': '',
#    'startTime': '2023-03-05T22:00:00-06:00',
#    'endTime': '2023-03-05T23:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#    'windSpeed': '22 mph',
#    'windDirection': 'SSE',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 57,
#    'name': '',
#    'startTime': '2023-03-05T23:00:00-06:00',
#    'endTime': '2023-03-06T00:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#    'windSpeed': '22 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 58,
#    'name': '',
#    'startTime': '2023-03-06T00:00:00-06:00',
#    'endTime': '2023-03-06T01:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#    'windSpeed': '22 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,9?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 59,
#    'name': '',
#    'startTime': '2023-03-06T01:00:00-06:00',
#    'endTime': '2023-03-06T02:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '21 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,9?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 60,
#    'name': '',
#    'startTime': '2023-03-06T02:00:00-06:00',
#    'endTime': '2023-03-06T03:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#    'windSpeed': '20 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/bkn,9?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 61,
#    'name': '',
#    'startTime': '2023-03-06T03:00:00-06:00',
#    'endTime': '2023-03-06T04:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 48,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#    'windSpeed': '18 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/bkn,9?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 62,
#    'name': '',
#    'startTime': '2023-03-06T04:00:00-06:00',
#    'endTime': '2023-03-06T05:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 47,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#    'windSpeed': '18 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 63,
#    'name': '',
#    'startTime': '2023-03-06T05:00:00-06:00',
#    'endTime': '2023-03-06T06:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 47,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#    'windSpeed': '18 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 64,
#    'name': '',
#    'startTime': '2023-03-06T06:00:00-06:00',
#    'endTime': '2023-03-06T07:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 47,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#    'windSpeed': '18 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,11?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 65,
#    'name': '',
#    'startTime': '2023-03-06T07:00:00-06:00',
#    'endTime': '2023-03-06T08:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 49,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#    'windSpeed': '18 mph',
#    'windDirection': 'S',
#    'icon': 'https://api.weather.gov/icons/land/day/sct,11?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 66,
#    'name': '',
#    'startTime': '2023-03-06T08:00:00-06:00',
#    'endTime': '2023-03-06T09:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 51,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.333333333333332},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#    'windSpeed': '18 mph',
#    'windDirection': 'SSW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 67,
#    'name': '',
#    'startTime': '2023-03-06T09:00:00-06:00',
#    'endTime': '2023-03-06T10:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 54,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 9.444444444444445},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#    'windSpeed': '20 mph',
#    'windDirection': 'SSW',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 68,
#    'name': '',
#    'startTime': '2023-03-06T10:00:00-06:00',
#    'endTime': '2023-03-06T11:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 57,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#    'windSpeed': '21 mph',
#    'windDirection': 'SSW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 69,
#    'name': '',
#    'startTime': '2023-03-06T11:00:00-06:00',
#    'endTime': '2023-03-06T12:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 59,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#    'windSpeed': '22 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 70,
#    'name': '',
#    'startTime': '2023-03-06T12:00:00-06:00',
#    'endTime': '2023-03-06T13:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 61,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 72},
#    'windSpeed': '23 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 71,
#    'name': '',
#    'startTime': '2023-03-06T13:00:00-06:00',
#    'endTime': '2023-03-06T14:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 63,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#    'windSpeed': '23 mph',
#    'windDirection': 'SW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 72,
#    'name': '',
#    'startTime': '2023-03-06T14:00:00-06:00',
#    'endTime': '2023-03-06T15:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 63,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#    'windSpeed': '23 mph',
#    'windDirection': 'WSW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 73,
#    'name': '',
#    'startTime': '2023-03-06T15:00:00-06:00',
#    'endTime': '2023-03-06T16:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 63,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 65},
#    'windSpeed': '22 mph',
#    'windDirection': 'WSW',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 74,
#    'name': '',
#    'startTime': '2023-03-06T16:00:00-06:00',
#    'endTime': '2023-03-06T17:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 61,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#    'windSpeed': '22 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_sct,10?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 75,
#    'name': '',
#    'startTime': '2023-03-06T17:00:00-06:00',
#    'endTime': '2023-03-06T18:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 59,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.88888888888889},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#    'windSpeed': '22 mph',
#    'windDirection': 'W',
#    'icon': 'https://api.weather.gov/icons/land/day/wind_sct,10?size=small',
#    'shortForecast': 'Mostly Sunny',
#    'detailedForecast': ''},
#   {'number': 76,
#    'name': '',
#    'startTime': '2023-03-06T18:00:00-06:00',
#    'endTime': '2023-03-06T19:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 56,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#    'windSpeed': '21 mph',
#    'windDirection': 'WNW',
#    'icon': 'https://api.weather.gov/icons/land/night/wind_sct,8?size=small',
#    'shortForecast': 'Partly Cloudy',
#    'detailedForecast': ''},
#   {'number': 77,
#    'name': '',
# ...
#    'name': '',
#    'startTime': '2023-03-09T02:00:00-06:00',
#    'endTime': '2023-03-09T03:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#    'shortForecast': 'Slight Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 133,
#    'name': '',
#    'startTime': '2023-03-09T03:00:00-06:00',
#    'endTime': '2023-03-09T04:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#    'shortForecast': 'Slight Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 134,
#    'name': '',
#    'startTime': '2023-03-09T04:00:00-06:00',
#    'endTime': '2023-03-09T05:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 31,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#    'shortForecast': 'Slight Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 135,
#    'name': '',
#    'startTime': '2023-03-09T05:00:00-06:00',
#    'endTime': '2023-03-09T06:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 30,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#    'shortForecast': 'Slight Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 136,
#    'name': '',
#    'startTime': '2023-03-09T06:00:00-06:00',
#    'endTime': '2023-03-09T07:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 30,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 137,
#    'name': '',
#    'startTime': '2023-03-09T07:00:00-06:00',
#    'endTime': '2023-03-09T08:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 31,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 138,
#    'name': '',
#    'startTime': '2023-03-09T08:00:00-06:00',
#    'endTime': '2023-03-09T09:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 139,
#    'name': '',
#    'startTime': '2023-03-09T09:00:00-06:00',
#    'endTime': '2023-03-09T10:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 140,
#    'name': '',
#    'startTime': '2023-03-09T10:00:00-06:00',
#    'endTime': '2023-03-09T11:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 35,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 66},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Partly Sunny',
#    'detailedForecast': ''},
#   {'number': 141,
#    'name': '',
#    'startTime': '2023-03-09T11:00:00-06:00',
#    'endTime': '2023-03-09T12:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 37,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 64},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#    'shortForecast': 'Mostly Cloudy',
#    'detailedForecast': ''},
#   {'number': 142,
#    'name': '',
#    'startTime': '2023-03-09T12:00:00-06:00',
#    'endTime': '2023-03-09T13:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 38,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 62},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 143,
#    'name': '',
#    'startTime': '2023-03-09T13:00:00-06:00',
#    'endTime': '2023-03-09T14:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 59},
#    'windSpeed': '14 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 144,
#    'name': '',
#    'startTime': '2023-03-09T14:00:00-06:00',
#    'endTime': '2023-03-09T15:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 40,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 145,
#    'name': '',
#    'startTime': '2023-03-09T15:00:00-06:00',
#    'endTime': '2023-03-09T16:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 40,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 146,
#    'name': '',
#    'startTime': '2023-03-09T16:00:00-06:00',
#    'endTime': '2023-03-09T17:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 39,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 59},
#    'windSpeed': '13 mph',
#    'windDirection': 'NE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 147,
#    'name': '',
#    'startTime': '2023-03-09T17:00:00-06:00',
#    'endTime': '2023-03-09T18:00:00-06:00',
#    'isDaytime': True,
#    'temperature': 38,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 64},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#    'shortForecast': 'Slight Chance Rain And Snow',
#    'detailedForecast': ''},
#   {'number': 148,
#    'name': '',
#    'startTime': '2023-03-09T18:00:00-06:00',
#    'endTime': '2023-03-09T19:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 37,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 149,
#    'name': '',
#    'startTime': '2023-03-09T19:00:00-06:00',
#    'endTime': '2023-03-09T20:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 36,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 150,
#    'name': '',
#    'startTime': '2023-03-09T20:00:00-06:00',
#    'endTime': '2023-03-09T21:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 34,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 151,
#    'name': '',
#    'startTime': '2023-03-09T21:00:00-06:00',
#    'endTime': '2023-03-09T22:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 33,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 152,
#    'name': '',
#    'startTime': '2023-03-09T22:00:00-06:00',
#    'endTime': '2023-03-09T23:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 153,
#    'name': '',
#    'startTime': '2023-03-09T23:00:00-06:00',
#    'endTime': '2023-03-10T00:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 154,
#    'name': '',
#    'startTime': '2023-03-10T00:00:00-06:00',
#    'endTime': '2023-03-10T01:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 155,
#    'name': '',
#    'startTime': '2023-03-10T01:00:00-06:00',
#    'endTime': '2023-03-10T02:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 32,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''},
#   {'number': 156,
#    'name': '',
#    'startTime': '2023-03-10T02:00:00-06:00',
#    'endTime': '2023-03-10T03:00:00-06:00',
#    'isDaytime': False,
#    'temperature': 31,
#    'temperatureUnit': 'F',
#    'temperatureTrend': None,
#    'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#    'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#    'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 85},
#    'windSpeed': '14 mph',
#    'windDirection': 'NNE',
#    'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#    'shortForecast': 'Chance Light Snow',
#    'detailedForecast': ''}]}

# %% [markdown]
# Finally, going even deeper, the `periods` key contains a data for each forecast period (each hour).  This is viewed by going two levels deep or `forecastJSON["properties"]["periods"]`:

# %%
forecastJSON["properties"]["periods"]
# Out:
# [{'number': 1,
#   'name': '',
#   'startTime': '2023-03-03T15:00:00-06:00',
#   'endTime': '2023-03-03T16:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 94},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#   'windSpeed': '32 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,94?size=small',
#   'shortForecast': 'Light Snow',
#   'detailedForecast': ''},
#  {'number': 2,
#   'name': '',
#   'startTime': '2023-03-03T16:00:00-06:00',
#   'endTime': '2023-03-03T17:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 87},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#   'windSpeed': '33 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,87?size=small',
#   'shortForecast': 'Light Snow',
#   'detailedForecast': ''},
#  {'number': 3,
#   'name': '',
#   'startTime': '2023-03-03T17:00:00-06:00',
#   'endTime': '2023-03-03T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '31 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,81?size=small',
#   'shortForecast': 'Heavy Snow',
#   'detailedForecast': ''},
#  {'number': 4,
#   'name': '',
#   'startTime': '2023-03-03T18:00:00-06:00',
#   'endTime': '2023-03-03T19:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 61},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '30 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,61?size=small',
#   'shortForecast': 'Rain And Snow Likely',
#   'detailedForecast': ''},
#  {'number': 5,
#   'name': '',
#   'startTime': '2023-03-03T19:00:00-06:00',
#   'endTime': '2023-03-03T20:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 35},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '29 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,35?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 6,
#   'name': '',
#   'startTime': '2023-03-03T20:00:00-06:00',
#   'endTime': '2023-03-03T21:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 21},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '26 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,21?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 7,
#   'name': '',
#   'startTime': '2023-03-03T21:00:00-06:00',
#   'endTime': '2023-03-03T22:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '24 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,10?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 8,
#   'name': '',
#   'startTime': '2023-03-03T22:00:00-06:00',
#   'endTime': '2023-03-03T23:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 4},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '22 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,4?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 9,
#   'name': '',
#   'startTime': '2023-03-03T23:00:00-06:00',
#   'endTime': '2023-03-04T00:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 33,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -0.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '17 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn,1?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 10,
#   'name': '',
#   'startTime': '2023-03-04T00:00:00-06:00',
#   'endTime': '2023-03-04T01:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '14 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 11,
#   'name': '',
#   'startTime': '2023-03-04T01:00:00-06:00',
#   'endTime': '2023-03-04T02:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 31,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '12 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 12,
#   'name': '',
#   'startTime': '2023-03-04T02:00:00-06:00',
#   'endTime': '2023-03-04T03:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 30,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '10 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 13,
#   'name': '',
#   'startTime': '2023-03-04T03:00:00-06:00',
#   'endTime': '2023-03-04T04:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 29,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '9 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 14,
#   'name': '',
#   'startTime': '2023-03-04T04:00:00-06:00',
#   'endTime': '2023-03-04T05:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 29,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '8 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 15,
#   'name': '',
#   'startTime': '2023-03-04T05:00:00-06:00',
#   'endTime': '2023-03-04T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 28,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '7 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 16,
#   'name': '',
#   'startTime': '2023-03-04T06:00:00-06:00',
#   'endTime': '2023-03-04T07:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 28,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '7 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,1?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 17,
#   'name': '',
#   'startTime': '2023-03-04T07:00:00-06:00',
#   'endTime': '2023-03-04T08:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 30,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,1?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 18,
#   'name': '',
#   'startTime': '2023-03-04T08:00:00-06:00',
#   'endTime': '2023-03-04T09:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '5 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 19,
#   'name': '',
#   'startTime': '2023-03-04T09:00:00-06:00',
#   'endTime': '2023-03-04T10:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '5 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 20,
#   'name': '',
#   'startTime': '2023-03-04T10:00:00-06:00',
#   'endTime': '2023-03-04T11:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 37,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '6 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,1?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 21,
#   'name': '',
#   'startTime': '2023-03-04T11:00:00-06:00',
#   'endTime': '2023-03-04T12:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 85},
#   'windSpeed': '6 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,1?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 22,
#   'name': '',
#   'startTime': '2023-03-04T12:00:00-06:00',
#   'endTime': '2023-03-04T13:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 42,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '7 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 23,
#   'name': '',
#   'startTime': '2023-03-04T13:00:00-06:00',
#   'endTime': '2023-03-04T14:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 43,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '8 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 24,
#   'name': '',
#   'startTime': '2023-03-04T14:00:00-06:00',
#   'endTime': '2023-03-04T15:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 45,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#   'windSpeed': '9 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,2?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 25,
#   'name': '',
#   'startTime': '2023-03-04T15:00:00-06:00',
#   'endTime': '2023-03-04T16:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 76},
#   'windSpeed': '9 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 26,
#   'name': '',
#   'startTime': '2023-03-04T16:00:00-06:00',
#   'endTime': '2023-03-04T17:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 45,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#   'windSpeed': '9 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 27,
#   'name': '',
#   'startTime': '2023-03-04T17:00:00-06:00',
#   'endTime': '2023-03-04T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 44,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '8 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,5?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 28,
#   'name': '',
#   'startTime': '2023-03-04T18:00:00-06:00',
#   'endTime': '2023-03-04T19:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 43,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '8 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 29,
#   'name': '',
#   'startTime': '2023-03-04T19:00:00-06:00',
#   'endTime': '2023-03-04T20:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 42,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '7 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 30,
#   'name': '',
#   'startTime': '2023-03-04T20:00:00-06:00',
#   'endTime': '2023-03-04T21:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 41,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '7 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 31,
#   'name': '',
#   'startTime': '2023-03-04T21:00:00-06:00',
#   'endTime': '2023-03-04T22:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 40,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '7 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 32,
#   'name': '',
#   'startTime': '2023-03-04T22:00:00-06:00',
#   'endTime': '2023-03-04T23:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '7 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 33,
#   'name': '',
#   'startTime': '2023-03-04T23:00:00-06:00',
#   'endTime': '2023-03-05T00:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 34,
#   'name': '',
#   'startTime': '2023-03-05T00:00:00-06:00',
#   'endTime': '2023-03-05T01:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 38,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '5 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 35,
#   'name': '',
#   'startTime': '2023-03-05T01:00:00-06:00',
#   'endTime': '2023-03-05T02:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 37,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few,0?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 36,
#   'name': '',
#   'startTime': '2023-03-05T02:00:00-06:00',
#   'endTime': '2023-03-05T03:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 36,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 37,
#   'name': '',
#   'startTime': '2023-03-05T03:00:00-06:00',
#   'endTime': '2023-03-05T04:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 38,
#   'name': '',
#   'startTime': '2023-03-05T04:00:00-06:00',
#   'endTime': '2023-03-05T05:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '5 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 39,
#   'name': '',
#   'startTime': '2023-03-05T05:00:00-06:00',
#   'endTime': '2023-03-05T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#   'windSpeed': '5 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,0?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 40,
#   'name': '',
#   'startTime': '2023-03-05T06:00:00-06:00',
#   'endTime': '2023-03-05T07:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,0?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 41,
#   'name': '',
#   'startTime': '2023-03-05T07:00:00-06:00',
#   'endTime': '2023-03-05T08:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 100},
#   'windSpeed': '7 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 42,
#   'name': '',
#   'startTime': '2023-03-05T08:00:00-06:00',
#   'endTime': '2023-03-05T09:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 36,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 96},
#   'windSpeed': '7 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 43,
#   'name': '',
#   'startTime': '2023-03-05T09:00:00-06:00',
#   'endTime': '2023-03-05T10:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 92},
#   'windSpeed': '8 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 44,
#   'name': '',
#   'startTime': '2023-03-05T10:00:00-06:00',
#   'endTime': '2023-03-05T11:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 42,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '9 mph',
#   'windDirection': 'ESE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 45,
#   'name': '',
#   'startTime': '2023-03-05T11:00:00-06:00',
#   'endTime': '2023-03-05T12:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '10 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 46,
#   'name': '',
#   'startTime': '2023-03-05T12:00:00-06:00',
#   'endTime': '2023-03-05T13:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '12 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/ovc,0?size=small',
#   'shortForecast': 'Cloudy',
#   'detailedForecast': ''},
#  {'number': 47,
#   'name': '',
#   'startTime': '2023-03-05T13:00:00-06:00',
#   'endTime': '2023-03-05T14:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#   'windSpeed': '13 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 48,
#   'name': '',
#   'startTime': '2023-03-05T14:00:00-06:00',
#   'endTime': '2023-03-05T15:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#   'windSpeed': '13 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 49,
#   'name': '',
#   'startTime': '2023-03-05T15:00:00-06:00',
#   'endTime': '2023-03-05T16:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#   'windSpeed': '14 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 50,
#   'name': '',
#   'startTime': '2023-03-05T16:00:00-06:00',
#   'endTime': '2023-03-05T17:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#   'windSpeed': '15 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 51,
#   'name': '',
#   'startTime': '2023-03-05T17:00:00-06:00',
#   'endTime': '2023-03-05T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#   'windSpeed': '17 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,0?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 52,
#   'name': '',
#   'startTime': '2023-03-05T18:00:00-06:00',
#   'endTime': '2023-03-05T19:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '18 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn,3?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 53,
#   'name': '',
#   'startTime': '2023-03-05T19:00:00-06:00',
#   'endTime': '2023-03-05T20:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '20 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,3?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 54,
#   'name': '',
#   'startTime': '2023-03-05T20:00:00-06:00',
#   'endTime': '2023-03-05T21:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '21 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 55,
#   'name': '',
#   'startTime': '2023-03-05T21:00:00-06:00',
#   'endTime': '2023-03-05T22:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '22 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 56,
#   'name': '',
#   'startTime': '2023-03-05T22:00:00-06:00',
#   'endTime': '2023-03-05T23:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '22 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 57,
#   'name': '',
#   'startTime': '2023-03-05T23:00:00-06:00',
#   'endTime': '2023-03-06T00:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '22 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct,3?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 58,
#   'name': '',
#   'startTime': '2023-03-06T00:00:00-06:00',
#   'endTime': '2023-03-06T01:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '22 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,9?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 59,
#   'name': '',
#   'startTime': '2023-03-06T01:00:00-06:00',
#   'endTime': '2023-03-06T02:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '21 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_bkn,9?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 60,
#   'name': '',
#   'startTime': '2023-03-06T02:00:00-06:00',
#   'endTime': '2023-03-06T03:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '20 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn,9?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 61,
#   'name': '',
#   'startTime': '2023-03-06T03:00:00-06:00',
#   'endTime': '2023-03-06T04:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '18 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn,9?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 62,
#   'name': '',
#   'startTime': '2023-03-06T04:00:00-06:00',
#   'endTime': '2023-03-06T05:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '18 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 63,
#   'name': '',
#   'startTime': '2023-03-06T05:00:00-06:00',
#   'endTime': '2023-03-06T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 9},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '18 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,9?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 64,
#   'name': '',
#   'startTime': '2023-03-06T06:00:00-06:00',
#   'endTime': '2023-03-06T07:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 89},
#   'windSpeed': '18 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,11?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 65,
#   'name': '',
#   'startTime': '2023-03-06T07:00:00-06:00',
#   'endTime': '2023-03-06T08:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '18 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/sct,11?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 66,
#   'name': '',
#   'startTime': '2023-03-06T08:00:00-06:00',
#   'endTime': '2023-03-06T09:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.333333333333332},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '18 mph',
#   'windDirection': 'SSW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 67,
#   'name': '',
#   'startTime': '2023-03-06T09:00:00-06:00',
#   'endTime': '2023-03-06T10:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 9.444444444444445},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '20 mph',
#   'windDirection': 'SSW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 68,
#   'name': '',
#   'startTime': '2023-03-06T10:00:00-06:00',
#   'endTime': '2023-03-06T11:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '21 mph',
#   'windDirection': 'SSW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 69,
#   'name': '',
#   'startTime': '2023-03-06T11:00:00-06:00',
#   'endTime': '2023-03-06T12:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '22 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 70,
#   'name': '',
#   'startTime': '2023-03-06T12:00:00-06:00',
#   'endTime': '2023-03-06T13:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 72},
#   'windSpeed': '23 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 71,
#   'name': '',
#   'startTime': '2023-03-06T13:00:00-06:00',
#   'endTime': '2023-03-06T14:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '23 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 72,
#   'name': '',
#   'startTime': '2023-03-06T14:00:00-06:00',
#   'endTime': '2023-03-06T15:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '23 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 73,
#   'name': '',
#   'startTime': '2023-03-06T15:00:00-06:00',
#   'endTime': '2023-03-06T16:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 65},
#   'windSpeed': '22 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_bkn,10?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 74,
#   'name': '',
#   'startTime': '2023-03-06T16:00:00-06:00',
#   'endTime': '2023-03-06T17:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '22 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_sct,10?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 75,
#   'name': '',
#   'startTime': '2023-03-06T17:00:00-06:00',
#   'endTime': '2023-03-06T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.88888888888889},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '22 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_sct,10?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 76,
#   'name': '',
#   'startTime': '2023-03-06T18:00:00-06:00',
#   'endTime': '2023-03-06T19:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#   'windSpeed': '21 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct,8?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 77,
#   'name': '',
#   'startTime': '2023-03-06T19:00:00-06:00',
#   'endTime': '2023-03-06T20:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#   'windSpeed': '20 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,8?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 78,
#   'name': '',
#   'startTime': '2023-03-06T20:00:00-06:00',
#   'endTime': '2023-03-06T21:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#   'windSpeed': '17 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct,8?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 79,
#   'name': '',
#   'startTime': '2023-03-06T21:00:00-06:00',
#   'endTime': '2023-03-06T22:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
# ...
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 132,
#   'name': '',
#   'startTime': '2023-03-09T02:00:00-06:00',
#   'endTime': '2023-03-09T03:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 133,
#   'name': '',
#   'startTime': '2023-03-09T03:00:00-06:00',
#   'endTime': '2023-03-09T04:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 134,
#   'name': '',
#   'startTime': '2023-03-09T04:00:00-06:00',
#   'endTime': '2023-03-09T05:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 31,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 135,
#   'name': '',
#   'startTime': '2023-03-09T05:00:00-06:00',
#   'endTime': '2023-03-09T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 30,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 19},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,19?size=small',
#   'shortForecast': 'Slight Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 136,
#   'name': '',
#   'startTime': '2023-03-09T06:00:00-06:00',
#   'endTime': '2023-03-09T07:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 30,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 137,
#   'name': '',
#   'startTime': '2023-03-09T07:00:00-06:00',
#   'endTime': '2023-03-09T08:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 31,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 138,
#   'name': '',
#   'startTime': '2023-03-09T08:00:00-06:00',
#   'endTime': '2023-03-09T09:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 139,
#   'name': '',
#   'startTime': '2023-03-09T09:00:00-06:00',
#   'endTime': '2023-03-09T10:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 140,
#   'name': '',
#   'startTime': '2023-03-09T10:00:00-06:00',
#   'endTime': '2023-03-09T11:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 35,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.888888888888888},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 66},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 141,
#   'name': '',
#   'startTime': '2023-03-09T11:00:00-06:00',
#   'endTime': '2023-03-09T12:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 37,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 11},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 64},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn,11?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 142,
#   'name': '',
#   'startTime': '2023-03-09T12:00:00-06:00',
#   'endTime': '2023-03-09T13:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 38,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 62},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 143,
#   'name': '',
#   'startTime': '2023-03-09T13:00:00-06:00',
#   'endTime': '2023-03-09T14:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 59},
#   'windSpeed': '14 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 144,
#   'name': '',
#   'startTime': '2023-03-09T14:00:00-06:00',
#   'endTime': '2023-03-09T15:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 40,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 145,
#   'name': '',
#   'startTime': '2023-03-09T15:00:00-06:00',
#   'endTime': '2023-03-09T16:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 40,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 146,
#   'name': '',
#   'startTime': '2023-03-09T16:00:00-06:00',
#   'endTime': '2023-03-09T17:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 39,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.333333333333333},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 59},
#   'windSpeed': '13 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 147,
#   'name': '',
#   'startTime': '2023-03-09T17:00:00-06:00',
#   'endTime': '2023-03-09T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 38,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 17},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 64},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,17?size=small',
#   'shortForecast': 'Slight Chance Rain And Snow',
#   'detailedForecast': ''},
#  {'number': 148,
#   'name': '',
#   'startTime': '2023-03-09T18:00:00-06:00',
#   'endTime': '2023-03-09T19:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 37,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 149,
#   'name': '',
#   'startTime': '2023-03-09T19:00:00-06:00',
#   'endTime': '2023-03-09T20:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 36,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 150,
#   'name': '',
#   'startTime': '2023-03-09T20:00:00-06:00',
#   'endTime': '2023-03-09T21:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 151,
#   'name': '',
#   'startTime': '2023-03-09T21:00:00-06:00',
#   'endTime': '2023-03-09T22:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 33,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 152,
#   'name': '',
#   'startTime': '2023-03-09T22:00:00-06:00',
#   'endTime': '2023-03-09T23:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 153,
#   'name': '',
#   'startTime': '2023-03-09T23:00:00-06:00',
#   'endTime': '2023-03-10T00:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 26},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,26?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 154,
#   'name': '',
#   'startTime': '2023-03-10T00:00:00-06:00',
#   'endTime': '2023-03-10T01:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 155,
#   'name': '',
#   'startTime': '2023-03-10T01:00:00-06:00',
#   'endTime': '2023-03-10T02:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''},
#  {'number': 156,
#   'name': '',
#   'startTime': '2023-03-10T02:00:00-06:00',
#   'endTime': '2023-03-10T03:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 31,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 39},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -2.777777777777777},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 85},
#   'windSpeed': '14 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/snow,39?size=small',
#   'shortForecast': 'Chance Light Snow',
#   'detailedForecast': ''}]

# %% [markdown]
# ### Loading the Data at a DataFrame
#
# Since we have **clean, structured data**, we can read it into pandas!  The code below creates a DataFrame out of the above data by using the `pd.DataFrame` command:

# %%
df = pd.DataFrame(forecastJSON["properties"]["periods"])
df
# Out:
#      number name                  startTime                    endTime  \
# 0         1       2023-03-03T15:00:00-06:00  2023-03-03T16:00:00-06:00
# 1         2       2023-03-03T16:00:00-06:00  2023-03-03T17:00:00-06:00
# 2         3       2023-03-03T17:00:00-06:00  2023-03-03T18:00:00-06:00
# 3         4       2023-03-03T18:00:00-06:00  2023-03-03T19:00:00-06:00
# 4         5       2023-03-03T19:00:00-06:00  2023-03-03T20:00:00-06:00
# ..      ...  ...                        ...                        ...
# 151     152       2023-03-09T22:00:00-06:00  2023-03-09T23:00:00-06:00
# 152     153       2023-03-09T23:00:00-06:00  2023-03-10T00:00:00-06:00
# 153     154       2023-03-10T00:00:00-06:00  2023-03-10T01:00:00-06:00
# 154     155       2023-03-10T01:00:00-06:00  2023-03-10T02:00:00-06:00
# 155     156       2023-03-10T02:00:00-06:00  2023-03-10T03:00:00-06:00
#
#      isDaytime  temperature temperatureUnit temperatureTrend  \
# 0         True           35               F             None
# 1         True           35               F             None
# 2         True           35               F             None
# 3        False           35               F             None
# 4        False           35               F             None
# ..         ...          ...             ...              ...
# 151      False           32               F             None
# 152      False           32               F             None
# 153      False           32               F             None
# 154      False           32               F             None
# 155      False           31               F             None
#
#                        probabilityOfPrecipitation  \
# 0    {'unitCode': 'wmoUnit:percent', 'value': 94}
# 1    {'unitCode': 'wmoUnit:percent', 'value': 87}
# 2    {'unitCode': 'wmoUnit:percent', 'value': 81}
# 3    {'unitCode': 'wmoUnit:percent', 'value': 61}
# 4    {'unitCode': 'wmoUnit:percent', 'value': 35}
# ..                                            ...
# 151  {'unitCode': 'wmoUnit:percent', 'value': 26}
# 152  {'unitCode': 'wmoUnit:percent', 'value': 26}
# 153  {'unitCode': 'wmoUnit:percent', 'value': 39}
# 154  {'unitCode': 'wmoUnit:percent', 'value': 39}
# 155  {'unitCode': 'wmoUnit:percent', 'value': 39}
#
#                                               dewpoint  \
# 0    {'unitCode': 'wmoUnit:degC', 'value': 1.666666...
# 1    {'unitCode': 'wmoUnit:degC', 'value': 1.666666...
# 2    {'unitCode': 'wmoUnit:degC', 'value': 1.111111...
# 3    {'unitCode': 'wmoUnit:degC', 'value': 1.111111...
# 4    {'unitCode': 'wmoUnit:degC', 'value': 0.555555...
# ..                                                 ...
# 151  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
# 152  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
# 153  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
# 154  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
# 155  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
#
#                                   relativeHumidity windSpeed windDirection  \
# 0    {'unitCode': 'wmoUnit:percent', 'value': 100}    32 mph           NNE
# 1    {'unitCode': 'wmoUnit:percent', 'value': 100}    33 mph             N
# 2     {'unitCode': 'wmoUnit:percent', 'value': 96}    31 mph             N
# 3     {'unitCode': 'wmoUnit:percent', 'value': 96}    30 mph             N
# 4     {'unitCode': 'wmoUnit:percent', 'value': 92}    29 mph           NNW
# ..                                             ...       ...           ...
# 151   {'unitCode': 'wmoUnit:percent', 'value': 81}    14 mph           NNE
# 152   {'unitCode': 'wmoUnit:percent', 'value': 81}    14 mph           NNE
# 153   {'unitCode': 'wmoUnit:percent', 'value': 81}    14 mph           NNE
# 154   {'unitCode': 'wmoUnit:percent', 'value': 81}    14 mph           NNE
# 155   {'unitCode': 'wmoUnit:percent', 'value': 85}    14 mph           NNE
#
#                                                   icon         shortForecast  \
# 0    https://api.weather.gov/icons/land/day/snow,94...            Light Snow
# 1    https://api.weather.gov/icons/land/day/snow,87...            Light Snow
# 2    https://api.weather.gov/icons/land/day/snow,81...            Heavy Snow
# 3    https://api.weather.gov/icons/land/night/snow,...  Rain And Snow Likely
# 4    https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
# ..                                                 ...                   ...
# 151  https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
# 152  https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
# 153  https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
# 154  https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
# 155  https://api.weather.gov/icons/land/night/snow,...     Chance Light Snow
#
#     detailedForecast
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 151
# 152
# 153
# 154
# 155
#
# [156 rows x 16 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Exploring Your Weather
#
# Now that you have the weather forecast for **your location** loaded into the DataFrame `df`, it's time to nerd out with it!

# %% [markdown]
# ### Your Warmest Upcoming Temperature
#
# Using your data, find the warmest temperature in the entire forecast!  Save that row as `df_warmest`:

# %%
df_warmest = df.nlargest(1, "temperature")
df_warmest
# Out:
#     number name                  startTime                    endTime  \
# 70      71       2023-03-06T13:00:00-06:00  2023-03-06T14:00:00-06:00
#
#     isDaytime  temperature temperatureUnit temperatureTrend  \
# 70       True           63               F             None
#
#                       probabilityOfPrecipitation  \
# 70  {'unitCode': 'wmoUnit:percent', 'value': 10}
#
#                                              dewpoint  \
# 70  {'unitCode': 'wmoUnit:degC', 'value': 11.11111...
#
#                                 relativeHumidity windSpeed windDirection  \
# 70  {'unitCode': 'wmoUnit:percent', 'value': 67}    23 mph            SW
#
#                                                  icon shortForecast  \
# 70  https://api.weather.gov/icons/land/day/wind_bk...  Partly Sunny
#
#    detailedForecast
# 70

# %% [markdown]
# ### Your Coldest Upcoming Temperature
#
# Using your data, find the coldest temperature in the entire forecast!  Save that row as `df_coldest`:

# %%
df_coldest = df.nsmallest(1, "temperature")
df_coldest
# Out:
#     number name                  startTime                    endTime  \
# 14      15       2023-03-04T05:00:00-06:00  2023-03-04T06:00:00-06:00
#
#     isDaytime  temperature temperatureUnit temperatureTrend  \
# 14      False           28               F             None
#
#                      probabilityOfPrecipitation  \
# 14  {'unitCode': 'wmoUnit:percent', 'value': 0}
#
#                                              dewpoint  \
# 14  {'unitCode': 'wmoUnit:degC', 'value': -2.77777...
#
#                                 relativeHumidity windSpeed windDirection  \
# 14  {'unitCode': 'wmoUnit:percent', 'value': 96}     7 mph             W
#
#                                                  icon  shortForecast  \
# 14  https://api.weather.gov/icons/land/night/sct,0...  Partly Cloudy
#
#    detailedForecast
# 14

# %% [markdown]
# ### Hours of Sky Conditions
#
# The `shortForecast` column provides a brief summary of the forecasted condition of the sky for each hour.  Create a DataFrame that contains a summary of upcoming sky conditions in only two columns:
#
# - `shortForecast`, and
# - `count`, containing the number of times that `shortForecast` appears in the forecast
#
# That means the summary will have the following structure:
#
# |    | shortForecast | count |
# | -- | ------------- | ----- |
# |  0 | Chance Light Rain | 6 |
# |  1 | Mostly Clear	| 11 |
# | ... | ... | ... |
#
# Save the summary in the `skySummary` variable:

# %%
skySummary = df.groupby('shortForecast').count()[['startTime']].rename(columns={'startTime': 'count'}).reset_index()
#df.groupby("shortForecast").agg("count").reset_index()
#skySummary[ ["shortForecast" , "startTime"]].rename(columns = {'startTime' : 'count'})
skySummary[ ["shortForecast" , "count"]]
# Out:
#                   shortForecast  count
# 0             Chance Light Snow     10
# 1                        Cloudy      1
# 2                    Heavy Snow      1
# 3                    Light Snow      2
# 4                  Mostly Clear      2
# 5                 Mostly Cloudy     29
# 6                  Mostly Sunny      9
# 7                 Partly Cloudy     33
# 8                  Partly Sunny     49
# 9          Rain And Snow Likely      1
# 10     Slight Chance Light Rain      6
# 11     Slight Chance Light Snow      7
# 12  Slight Chance Rain And Snow      6

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Create a Scatter Plot
#
# Finally, let's create a scatter plot of your forecast!
#
# Using `df.plot.scatter`, you must specify the `x` column name and `y` column name for your scatter plot to use the command:
#
# ```
# df.plot.scatter(x="x-column", y="y-column")
# ```
#
# Using your weather forecast:
#
# - Use the starting date of the forecast as your `x` value,
# - Use the temperature as your `y` value,
# - Create your scatter plot! :)

# %%
df.plot.scatter( x = "startTime" , y = "temperature")
# Out:
# <Axes: xlabel='startTime', ylabel='temperature'>

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 Microproject Checkpoint Tests 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for the microproject.
# - If this cell runs without any error in the output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cells, make changes, and RE-RUN your code and then this cell.
tada = "\N{PARTY POPPER}"

assert("/points/" in pointsJSON["id"])
assert(f"/{int(latitude)}" in pointsJSON["id"])
assert(f",{int(longitude)}" in pointsJSON["id"])
assert("/gridpoints/" in hourlyForecastURL)
assert("/forecast/hourly" in hourlyForecastURL)
print(f"{tada} Data API: All Tests Passed! {tada}")


assert("df" in vars())
assert("startTime" in df)
assert("temperature" in df)
print(f"{tada} Puzzle 1: All Tests Passed! {tada}")


assert( len(df_warmest) == 1 )
assert( df_warmest["temperature"].values[0] == max(df["temperature"]) )

assert( len(df_coldest) == 1 )
assert( df_coldest["temperature"].values[0] == min(df["temperature"]) )

assert( len(skySummary) == len(df["shortForecast"].unique()) )
pd.testing.assert_frame_equal(skySummary.sort_values(["count", "shortForecast"]).set_index("shortForecast"), pd.DataFrame(df["shortForecast"].value_counts()).reset_index().rename({"index": "shortForecast", "shortForecast": "count"}, axis=1).sort_values(["count", "shortForecast"]).set_index("shortForecast")), "Your skySummary is incorrect."
print(f"{tada} Puzzle 2: All Tests Passed! {tada}")

print(f"{tada}{tada} All Tests Passed! {tada}{tada}")
# Out:
# 🎉 Data API: All Tests Passed! 🎉
# 🎉 Puzzle 1: All Tests Passed! 🎉
# 🎉 Puzzle 2: All Tests Passed! 🎉
# 🎉🎉 All Tests Passed! 🎉🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the instructions to commit and grade this MicroProject!
