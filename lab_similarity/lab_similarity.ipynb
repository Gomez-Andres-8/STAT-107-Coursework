# %% [markdown]
# # Welcome to Lab: Similarity 🧍🧍‍♂️🧍‍♀️
#
# Many of you already know your tablemates in this class. However, have you ever wondered if there is someone **even more similar** to you than the people you already know?
#
# In this lab, we'll once again explore the dataset from the **Hello Survey** you've completed, utilizing some new Python skills to calculate your similarity to your peers!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Kim"
ca1_name = "Jessica"
ca2_name = "Sony"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: What's your favorite (or least favorite) building on campus? 
partner1_name = "Aamir"
partner1_netid = "aabjani2"
partner1_favbuilding = "GIES"

partner2_name = "Brianna"
partner2_netid = "bfons2"
partner2_favbuilding = "English"

partner3_name = "Brian"
partner3_netid = "bzilles"
partner3_favbuilding = "Siebel"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello, Again

# %% [markdown]
# ## Load the Hello Dataset
# To find those most similar to you in this course, we're going to need the good old Hello Dataset.
#
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp23.csv
# ```
#
# Use Python to load this dataset into a DataFrame `df`:

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-sp23.csv")

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df" in vars()), "This is not the Hello dataset you're looking for. Check the URL."
assert("What is your favorite food?" in df), "This is not the Hello dataset you're looking for. Check the URL."
assert(len(df) >= 373), "This is not the Hello dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Finding Yourself
# There is no finding people you are **similar to** before finding **yourself** - literally!
#
# ### Puzzle 1.1: Your Row
# In the following cell, write the Python code to create a **new** DataFrame with only yourself, named `df_me`:

# %%
df_me = df[ df.Name == "Andres"]
df_me
# Out:
#        Name Section Are you a "Type A" or "Type B" personality?  \
# 236  Andres     AYA       Type B (patient, flexible, laid-back)
#
#     Are you a morning person? Are you an international student?  \
# 236                        No                                No
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 236                     No                                Yes
#
#     Do you consider your home to be in the United States or Abroad?  \
# 236                                      United States
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 236                          In-State             No  ...
#
#     What college is your major a part of?  \
# 236                                   LAS
#
#     What do you think is the hardest college major?  \
# 236                          Mechanical Engineering
#
#     What genre of music do you listen to?  \
# 236                                 Mixed
#
#     What is the best boba place in Urbana-Champaign?  \
# 236                                              NaN
#
#     What is your favorite color? What is your favorite food?  \
# 236                        Green                       Tacos
#
#     What is your favorite music artist? What is your favorite TV show?  \
# 236                               Logic                  Lost in Space
#
#     What's your favorite social media app?  \
# 236                                Youtube
#
#     Which European country would you like to visit?
# 236                                         Iceland
#
# [1 rows x 91 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df_me" in vars()), "Make sure you named the DataFrame with just you `df_me`"
assert("What is your favorite food?" in df_me), "Your `df_me` should have the same columns as our `df`."
assert(len(df_me.columns.to_list()) == 91), "Your `df_me` should have the same number of columns as our original `df`."
assert(len(df_me) == 1), "Your `df_me` should only have one row: yourself"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Dataframe vs. Series
#
# Before we continue, a brief lesson on some of the datatypes you'll encounter in this class.
#
# In `pandas`, there are three data structures we will be using, two of which you have already seen:
#
# - A **DataFrame** is similar to an Excel sheet. It contains zero or more rows and zero or more columns. It can contain up to an unlimited number of rows and columns and is the basic data structure we've worked with from the start
#
# - A **GroupBy** is a grouping of rows within a DataFrame. This "three dimensional data" requires us to use `agg` to reduce it back down to a DataFrame - which you've been doing in homeworks and labs thus far!
#
# - A **Series** is a single row with zero or more values (columns). You can think of a DataFrame as a collection of **Series** objects. When we deal with a single row, we will usually want to deal with a **Series** instead of a **one row DataFrame**
#
# In this lab, we will learn how to convert from a **one row DataFrame** to a **Series**, but here's a quick recap on how to convert from types:

# %% [markdown]
# ### Converting Types
#
# The `pandas` library makes it easy to convert between a **Series**, **DataFrame**, and **GroupBy**.
#
# - From a **Series** (`row`) to a **DataFrame**
#     - `row.to_frame()`
# - From a **DataFrame** (`df`) to a **GroupBy**:
#     - `df.groupby('columnName')` -- (You know this already!)
# - From a **GroupBy** (`group`) to a **DataFrame**:
#     - `df.agg( function )` -- (You know this already!)
# - From a **DataFrame** (`df`) to a **Series**:
#     - `df.iloc[0]`, if the DataFrame has one row
#
# See this guide, https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/dataframe-loc-vs-iloc/, for more information about `iloc[]`.

# %% [markdown]
# ### Puzzle 1.2: Transform your row into a Series
# Using the correct function from above, **transform** the `df_me` row containing only you from a **one-row DataFrame** into a **Series**.
#
# Make sure the Series is named `my_row` (this will match up with code we provide you with later):

# %%
my_row = df_me.iloc[0]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('my_row' in vars()), "Your series should be named `my_row`."
assert(type(my_row) == pd.core.series.Series), "Make sure you've correctly converted your one-row DataFrame into a Series..."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Choosing Your Columns

# %% [markdown]
# Before we begin, we have to think about our approach to finding your DISCOVERY twin.
#
# You may have noticed our Hello Dataset has **almost 100 questions**. Instead of finding the most similar person to you using **every question**, we'll pick out a few questions to analyze.
#
# **But first, we need to revisit the questions.**
#
# Recall the function `df.columns.tolist()`. To recap, this command will list **all of the columns** (in this case, our questions) in a DataFrame.
#
#  Use `df.columns.tolist()` in the cell below.
#
# You wil likely see the message: Output exceeds the __size limit__. Open the full output data __in a text editor__
#
# If you do, click the **in a text editor** link to open the whole list in a new tab of VSCode.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Are you a "Type A" or "Type B" personality?',
#  'Are you a morning person?',
#  'Are you an international student?',
#  'Are you an only child?',
#  'Are you from the Chicagoland area?',
#  'Do you consider your home to be in the United States or Abroad?',
#  'Are you in-state or out-of-state?',
#  'Are you tired?',
#  'Beaches or mountains?',
#  'Did you go to DISCOVERY lecture on Friday?',
#  'Do you eat breakfast?',
#  'Do you enjoy winter break or spring break more?',
#  'Do you have a MacBook?',
#  'Do you have a pet?',
#  'Do you have an "A" anywhere in your first name?',
#  'Do you have black hair?',
#  'Do you have long or short hair?',
#  'Do you like blue or red?',
#  'Do you like ice cream?',
#  'Do you like pineapple on pizza?',
#  'Do you like school?',
#  'Do you like snow?',
#  'Do you like spicy food?',
#  'Do you like the color green?',
#  'Do you prefer apples or oranges?',
#  'Do you prefer cauliflower or broccoli?',
#  'Do you prefer chocolate or vanilla ice cream?',
#  'Do you prefer Coke or Pepsi?',
#  'Do you prefer dark chocolate or white chocolate?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Do you prefer left over pizza hot or cold?',
#  "Do you prefer M&M's and Skittles?",
#  'Do you prefer Messi or Ronaldo?',
#  'Do you prefer mom or dad?',
#  'Do you prefer Nike or Adidas?',
#  'Do you prefer spicy or sweet food?',
#  'Do you prefer Spring or Fall?',
#  'Do you prefer staying in or going out?',
#  'Do you prefer still or sparkling water?',
#  'Do you prefer summer or winter?',
#  'Do you prefer sweet or salty snacks?',
#  'Do you prefer to eat at the Ikenberry or PAR?',
#  'Do you prefer to take notes by hand or digitally? (Not restricted to DISCOVERY)',
#  'Do you prefer Windows or macOS?',
#  'Do you prefer yellow or purple?',
#  'Do you prioritize yourself first or others?',
#  'Do you speak Chinese?',
#  'Do you own a Macbook?',
#  'Do you walk to class or take the bus?',
#  'Do you wear glasses?',
#  'Green grapes or purple grapes?',
#  'If a coin were flipped, what side do you think it would land on?',
#  'Is a glass half empty or half full?',
#  'Is DISCOVERY your favorite course this semester?',
#  "Is your last name's first letter > 'L' in alphabetical order?",
#  'Pancakes or Waffles?',
#  'Splitting the room in half, what side are you sitting in (left or right)?',
#  "Starbucks or Dunkin' Donuts?",
#  'The DAY OF THE MONTH of your birth is a even number or a odd number? (ex. Jan 12th is even and Dec 17th is odd)',
#  'Were you born in Illinois?',
#  'Were you born in the first half of the year or second half of the year?',
#  'Will 50% of you split up into a group?',
#  'Would you classify "many" as 5 or 10?',
#  'Do you enjoy/would you like to try a roller coaster?',
#  'Would you rather cough all the time or sneeze all the time?',
#  'For an review session before an exam, prefer it in-person and recorded or zoom and recorded?',
#  'Yanny or Laurel?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'How old are you?',
#  'In the past year, how many times have you been to the party?',
#  'What month were you born in (1-12)?',
#  "What's your favorite number from 1 through 10?",
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  'Favorite City in the United States',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your major a part of?',
#  'What do you think is the hardest college major?',
#  'What genre of music do you listen to?',
#  'What is the best boba place in Urbana-Champaign?',
#  'What is your favorite color?',
#  'What is your favorite food?',
#  'What is your favorite music artist?',
#  'What is your favorite TV show?',
#  "What's your favorite social media app?",
#  'Which European country would you like to visit?']

# %% [markdown]
# ### Puzzle 1.3: Choosing Your Columns
# From the above list of **columns** (questions), choose **at least 12 questions** to work with moving forward.
#
# These will be the questions used to **calculate your similarity** to other people in DISCOVERY! Feel free to include more if you'd like.
#
# Store them as a **list** of **strings** named `questions` in the Python cell below:

# %%
questions = [ 'Are you a "Type A" or "Type B" personality?', 
             'Do you like pineapple on pizza?' , 
             "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?" ,
             'Would you rather cough all the time or sneeze all the time?',
             'How many hours do you sleep in a day?',
             'How many siblings do you have?',
             'How old are you?',
             'Is a glass half empty or half full?' ,
             'Do you like the color green?' ,
             'Do you prefer staying in or going out?' ,
             'Do you prioritize yourself first or others?' ,
             'Do you prefer left over pizza hot or cold?'
]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('questions' in vars()), "Please name your list of questions `questions`."
assert(type(questions) == list and type(questions[0]) == str), "Make sure your `questions` variable is a list of strings"
assert(len(questions) >= 12), "Do you have at least 12 questions in your columns list?"
for q in questions:
   assert(q in df), "Double check that you've copied each question correctly. The question texts should match up EXACTLY with the output from `df.columns.to_list()`"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Question Choice
#
# **Q1: Explain why you chose the questions you did to evaluate similarity. Is there a question or questions you think that say more about someone than others?**

# %% [markdown]
# *(✏️ Yes I tried to pick out some questions that would best describe a person and then I also picked out some that were a bit weird to bring out how weirdly similar I am to someone else. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: The Similarity Function

# %% [markdown]
# Now that we have chosen the **questions** we'd like to evaluate off of, it's time to create a **function** to calculate a similarity value for each person, or each row in `df`.
#
# In lecture, remember learning that a Python **function** takes an **input** in and **returns** a **value**.
#
# For this specific function, we will take a **row** and calculate a **similarity score** for that row.
#
# But first, **print your list of questions** using the Python cell below for reference:

# %%
print(questions)
# Out:
# ['Are you a "Type A" or "Type B" personality?', 'Do you like pineapple on pizza?', "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?", 'Would you rather cough all the time or sneeze all the time?', 'How many hours do you sleep in a day?', 'How many siblings do you have?', 'How old are you?', 'Is a glass half empty or half full?', 'Do you like the color green?', 'Do you prefer staying in or going out?', 'Do you prioritize yourself first or others?', 'Do you prefer left over pizza hot or cold?']

# %% [markdown]
# ### Puzzle 2.1: The Similarity Function
# We have provided the basic outline for the `similarity` function below. Follow the **commented details** and **complete the function** using all of your questions below:

# %%
def similarity(row):
    # This function will keep track of a `score` of how similar two rows are with each other.
    # The score begins at zero and we will add to it every time a row matches.
    score = 0 

    # This if statement below checks to see if the `row` shares your choice between Pancakes and Waffles
    # - If the values are the same (==), we add one to the score.
    if row['Are you a "Type A" or "Type B" personality?'] == my_row['Are you a "Type A" or "Type B" personality?']:
        score = score + 1
    if row['Do you like pineapple on pizza?'] == my_row['Do you like pineapple on pizza?']:
        score = score + 1
    if row["The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?"] == my_row["The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?"]:
        score = score + 1
    if row['Would you rather cough all the time or sneeze all the time?'] == my_row['Would you rather cough all the time or sneeze all the time?']:
        score = score + 1
    if row['How many hours do you sleep in a day?'] == my_row['How many hours do you sleep in a day?']:
        score = score + 1
    if row['How many siblings do you have?'] == my_row['How many siblings do you have?']:
        score = score + 1
    if row['How old are you?'] == my_row['How old are you?']:
        score = score + 1
    if row['Is a glass half empty or half full?'] == my_row['Is a glass half empty or half full?']:
        score = score + 1
    if row['Do you like the color green?'] == my_row['Do you like the color green?']:
        score = score + 1
    if row['Do you prioritize yourself first or others?'] == my_row['Do you prioritize yourself first or others?']:
        score = score + 1
    if row['Do you prefer staying in or going out?'] == my_row['Do you prefer staying in or going out?']:
        score = score + 1
    if row['Do you prefer left over pizza hot or cold?'] == my_row['Do you prefer left over pizza hot or cold?']:
        score = score + 1
    

    # Repeat this syntax many times for EACH question (column) that you have chosen in your list
    # IMPORTANT: Make sure to keep your lines all at this same level of tabbing out from the start.    
    # ALSO: Delete or the replace the "Pancakes or Waffles?" question,
    #       (unless you've decided that is one of your evaluating questions). 

    # Finally, return the `score`.
    # ...this line (the return statement) should always be the LAST line. 
    return score

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(similarity(my_row) == len(questions) or similarity(my_row) == my_row[questions].count()), "Ensure you've added all the questions from your list and ONLY questions from your list correctly to your similarity function."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Applying the Similarity Function
# Now that you've properly defined the similarity function, we need to **apply** it to the rest of the Hello Dataset DataFrame so we can produce a **similarity score** for each person who took the survey!
#
# Luckily, `pandas` provides a useful function for our use case: `df.apply()`.
#
# Quick lesson: `df.apply(some_function)` applies a pre-defined function named `some_function` along an axis of your DataFrame.
#
# Because we want to run our `similarity` function on all **rows**, when you call `df.apply()`, ensure you use **`axis=1`**. This would look something like:
# ```
# df["score"] = df.apply(some_function, axis=1)
# ```
#
# Using the above explanation as reference, **add a column** named `Similarity Score` to your original DataFrame that contains the value after running your similarity function you defined earlier across all rows:

# %%
df["Similarity Score"] = df.apply(similarity, axis=1)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('Similarity Score' in df), "Make sure you've named and added the Similarity Score column to your original df"
assert(df['Similarity Score'].dtype == 'int64'), "Double check that you've called the similarity function correctly in your df.apply()"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Finding your Twin(s)

# %% [markdown]
# Your last column `Similarity Score` in `df` is now a metric (a measurement) of how **similar** you are to everyone else in the class, based on the **questions you've chose**!
#
# Finally, we can do analytical Data Science!

# %% [markdown]
# ### Puzzle 3.1: Your Twin in 107
#
# Using the Python cell below, find the **person most similar to you in the entire course** (having the largest `Similarity Score`).
#
# Note that **you should be most similar to yourself** (you will always match yourself)! This is not the right answer. Find the person with the highest score ***aside from yourself***.

# %%
df.nlargest(11, "Similarity Score")
# Out:
#               Name   Section  Are you a "Type A" or "Type B" personality?  \
# 236         Andres       AYA        Type B (patient, flexible, laid-back)
# 75        Jonathan       AYB        Type B (patient, flexible, laid-back)
# 189          Eshan       AYI        Type B (patient, flexible, laid-back)
# 237          Danny       AYE  Type A (ambitious, competitive, aggressive)
# 0       Prof Karle       AL1        Type B (patient, flexible, laid-back)
# 64          ishaan       AYA        Type B (patient, flexible, laid-back)
# 73   TA Evangelos   AYE, AYI        Type B (patient, flexible, laid-back)
# 153          Aditi       AYI        Type B (patient, flexible, laid-back)
# 323           Josh       AYI        Type B (patient, flexible, laid-back)
# 7            Arjun       AYE        Type B (patient, flexible, laid-back)
# 12        Richard        AYE  Type A (ambitious, competitive, aggressive)
#
#     Are you a morning person? Are you an international student?  \
# 236                        No                                No
# 75                         No                                No
# 189                        No                               Yes
# 237                        No                                No
# 0                          No                                No
# 64                        Yes                                No
# 73                        Yes                               Yes
# 153                        No                                No
# 323                       Yes                                No
# 7                          No                                No
# 12                         No                                No
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 236                     No                                Yes
# 75                      No                                 No
# 189                     No                                 No
# 237                     No                                Yes
# 0                       No                                 No
# 64                      No                                Yes
# 73                      No                                 No
# 153                     No                                 No
# 323                     No                                Yes
# 7                       No                                Yes
# 12                      No                                Yes
#
#     Do you consider your home to be in the United States or Abroad?  \
# 236                                      United States
# 75                                       United States
# 189                                             Abroad
# 237                                      United States
# 0                                        United States
# 64                                       United States
# 73                                       United States
# 153                                      United States
# 323                                      United States
# 7                                        United States
# 12                                       United States
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 236                          In-State             No  ...
# 75                           In-State             No  ...
# 189                      Out-of-State             No  ...
# 237                          In-State            Yes  ...
# 0                            In-State            Yes  ...
# 64                           In-State            Yes  ...
# 73                       Out-of-State             No  ...
# 153                      Out-of-State            Yes  ...
# 323                          In-State             No  ...
# 7                            In-State            Yes  ...
# 12                           In-State            Yes  ...
#
#     What do you think is the hardest college major?  \
# 236                          Mechanical Engineering
# 75                                               CS
# 189                                         Physics
# 237                                         Physics
# 0                                  Computer Science
# 64                                             meat
# 73                                      Mathematics
# 153                                            Math
# 323                          Electrical engineering
# 7                                                CS
# 12                      one of the engineering ones
#
#     What genre of music do you listen to?  \
# 236                                 Mixed
# 75                            Hip-hop/rap
# 189                               Hip-hop
# 237                                   Rap
# 0                                     pop
# 64                                    rap
# 73                             Rock music
# 153                                   Pop
# 323                                 indie
# 7                                     Rap
# 12                                    rap
#
#     What is the best boba place in Urbana-Champaign?  \
# 236                                              NaN
# 75                                               KFT
# 189                                      Kung Fu Tea
# 237                                              NaN
# 0                                              LaTea
# 64                                           teamoji
# 73                                      I don't know
# 153                                          Teamoji
# 323                                        bearology
# 7                                        Kung Fu Tea
# 12                               Never had Boba here
#
#     What is your favorite color? What is your favorite food?  \
# 236                        Green                       Tacos
# 75                           Red                    Soondubu
# 189                         Blue                     Paneer
# 237                       Orange                       Pizza
# 0                           pink                       Tacos
# 64                          gold                      paneer
# 73                          Grey                       Pasta
# 153                       Green                     Popcorn
# 323                       purple                       pizza
# 7                         Purple                    Burritos
# 12                        Yellow                       Wings
#
#     What is your favorite music artist?    What is your favorite TV show?  \
# 236                               Logic                     Lost in Space
# 75                            Quasimoto                      The Sopranos
# 189                          IceJJFish   Fullmetal Alchemist: Brotherhood
# 237                               Kanye                         West Wing
# 0                          Taylor Swift       How to Get Away with Murder
# 64                                kanye                          seinfeld
# 73                          Hilary Hahn                              Dark
# 153                              Mitski                         Sherlock
# 323                         still woozy                          mr.robot
# 7                              Lil Durk                      Breaking Bad
# 12                           Juice Wrld                         Community
#
#     What's your favorite social media app?  \
# 236                                Youtube
# 75                               Instagram
# 189                                Discord
# 237                               Snapchat
# 0                                Instagram
# 64                                snapchat
# 73                              Instagram
# 153                              Instagram
# 323                                Youtube
# 7                                 Snapchat
# 12                               Instagram
#
#     Which European country would you like to visit? Similarity Score
# 236                                         Iceland               12
# 75                                            Spain               10
# 189                                         Germany               10
# 237                                          London               10
# 0                                             Italy                9
# 64                                            Spain                9
# 73                                          Denmark                9
# 153                                     Netherlands                9
# 323                                          greece                9
# 7                                             Spain                8
# 12                                             None                8
#
# [11 rows x 92 columns]

# %% [markdown]
# ### Analysis: True Twin?
#
# **Q2: If you picked twelve or more other questions to evaluate similarity, do you think you'd find a different twin in the course overall?**

# %% [markdown]
# *(✏️ I think I would since this lab's results depend on the questions you choose ✏️)*

# %% [markdown]
# ### Puzzle 3.2: Your Lab Twin
#
# Now, chances are your twin isn't in your lab section. Because we conveniently have our row, `Similarity Score` applied to the **entire** set of responses to the survey, we can create smaller DataFrames to answer more questions.
#
# Using the Python cell below, find the person most similar to you in **your lab section**. Creating a new DataFrame might help.
#
# Hint: The column that stores lab sections from our Hello Survey is named `Section`.

# %%
similar_section = df[ df.Section == "AYA"].nlargest(11, "Similarity Score")
similar_section
# Out:
#            Name Section  Are you a "Type A" or "Type B" personality?  \
# 236      Andres     AYA        Type B (patient, flexible, laid-back)
# 64       ishaan     AYA        Type B (patient, flexible, laid-back)
# 47         Jack     AYA        Type B (patient, flexible, laid-back)
# 358        Evan     AYA  Type A (ambitious, competitive, aggressive)
# 66       Jeremy     AYA  Type A (ambitious, competitive, aggressive)
# 117      Otniel     AYA        Type B (patient, flexible, laid-back)
# 146  CA Jessica     AYA        Type B (patient, flexible, laid-back)
# 171       Yajat     AYA        Type B (patient, flexible, laid-back)
# 172        Todd     AYA  Type A (ambitious, competitive, aggressive)
# 302       Aamir     AYA        Type B (patient, flexible, laid-back)
# 314        Jake     AYA        Type B (patient, flexible, laid-back)
#
#     Are you a morning person? Are you an international student?  \
# 236                        No                                No
# 64                        Yes                                No
# 47                         No                                No
# 358                       NaN                                No
# 66                         No                                No
# 117                       Yes                                No
# 146                        No                                No
# 171                        No                               Yes
# 172                       Yes                                No
# 302                        No                                No
# 314                        No                                No
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 236                     No                                Yes
# 64                      No                                Yes
# 47                      No                                Yes
# 358                     No                                Yes
# 66                      No                                Yes
# 117                     No                                Yes
# 146                    Yes                                 No
# 171                    Yes                                 No
# 172                     No                                Yes
# 302                     No                                Yes
# 314                     No                                Yes
#
#     Do you consider your home to be in the United States or Abroad?  \
# 236                                      United States
# 64                                       United States
# 47                                       United States
# 358                                      United States
# 66                                       United States
# 117                                      United States
# 146                                      United States
# 171                                             Abroad
# 172                                      United States
# 302                                      United States
# 314                                      United States
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 236                          In-State             No  ...
# 64                           In-State            Yes  ...
# 47                           In-State             No  ...
# 358                          In-State            NaN  ...
# 66                           In-State             No  ...
# 117                          In-State             No  ...
# 146                      Out-of-State            Yes  ...
# 171                      Out-of-State            Yes  ...
# 172                          In-State             No  ...
# 302                          In-State             No  ...
# 314                          In-State            Yes  ...
#
#        What do you think is the hardest college major?  \
# 236                             Mechanical Engineering
# 64                                                meat
# 47                                 Systems in Grainger
# 358  I don't think there is one universally challen...
# 66                                         engineering
# 117                                   computer science
# 146                                                ECE
# 171                                                 EE
# 172                                                ECE
# 302                                                 CS
# 314                                                 CS
#
#     What genre of music do you listen to?  \
# 236                                 Mixed
# 64                                    rap
# 47                                    EDM
# 358                           Alternative
# 66                       Alternative Rock
# 117                                 indie
# 146                                 Indie
# 171                                   Pop
# 172                                  Rock
# 302                                   Rap
# 314                                  Rock
#
#     What is the best boba place in Urbana-Champaign?  \
# 236                                              NaN
# 64                                           teamoji
# 47                                    Not sure sorry
# 358                                          Teamoji
# 66                                         Tenko Tea
# 117                                          teamoji
# 146                                            Tenko
# 171                               Paris Super Crepes
# 172                                              Idk
# 302                                      Kung Fu Tea
# 314                                         Boba tea
#
#     What is your favorite color? What is your favorite food?  \
# 236                        Green                       Tacos
# 64                          gold                      paneer
# 47                          Blue                       Tacos
# 358                          Red                       Sushi
# 66                         green                      Salmon
# 117                          red                       bacon
# 146                   Periwinkle                       Tacos
# 171                         Blue                       Pizza
# 172                          Red                       Steak
# 302                         Blue                 Curry Kousa
# 314                         Blue                       Pasta
#
#     What is your favorite music artist?   What is your favorite TV show?  \
# 236                               Logic                    Lost in Space
# 64                                kanye                         seinfeld
# 47                          John Summit                            Ozark
# 358                                Rush                     Breaking Bad
# 66                          The Strokes                      Top Gear UK
# 117                          the weeknd            How I met Your Mother
# 146                      The Happy Fits  Fullmetal Alchemist:Brotherhood
# 171                                MGMT               Two and a Half Men
# 172                       David Gilmore                   Peaky Blinders
# 302                Yeat, Carti, or  Uzi                     All American
# 314                        Guns n Roses                     Breaking bad
#
#     What's your favorite social media app?  \
# 236                                Youtube
# 64                                snapchat
# 47                               Instagram
# 358                                    NaN
# 66                                 youtube
# 117                                YouTube
# 146                              Instagram
# 171                              Instagram
# 172                               Snapchat
# 302                                 TikTok
# 314                                Twitter
#
#     Which European country would you like to visit? Similarity Score
# 236                                         Iceland               12
# 64                                            Spain                9
# 47                                           Sweden                8
# 358                                       Amsterdam                8
# 66                                            Italy                7
# 117                                          France                7
# 146                                     Switzerland                7
# 171                                          France                7
# 172                                          Greece                7
# 302                                           Spain                7
# 314                                     Switzerland                7
#
# [11 rows x 92 columns]

# %% [markdown]
# #### **➡️ Right now, once you have that person, find them in lab!**<br>➡️ *(If they're not here, look for the next similar person.)*
#
# Help them finish their lab and let them find their DISCOVERY twin!  *(Are you twins of each other?)*
#
# Note that there may be ties in `Similarity Score` due to the usage of only parts of the dataset. If you're curious, you can go back and **add more questions** to your `questions` list and `similarity(row)` function, rerunning the code to have more evaluative similarity scores.

# %% [markdown]
# ### Puzzle 3.3: The Course Staff
# A lot of wonderful course staff work together to bring you all the content for Data Science Discovery.
#
# The course staff of 107 consists of the **Professors, TAs, and CAs**. They've all completed the Hello Survey too!
#
# Their response under the `name` column is standardized and follows these formats:
# - `Prof [Name]`,
# - `TA [Name]`, or
# - `CA [Name]`
#
# But how can we create a new DataFrame with just the course staff? Python saves the day again.
#
# #### **The `contains` Function**
# In Python, the `contains` function can be used to check if a specific **substring** is present in a **string**
#
# This will come in handy for us, because we can see if `"CA "`, `"TA "`, or `"Prof "` is in the **names** of any rows in our DataFrame
#
# Using the `contains` function, create a **new DataFrame** with just the course staff: `df_staff`.
#
# Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`

# %%
df_staff = df[(df['Name'].str.contains('CA ')) + (df['Name'].str.contains('TA ')) + (df['Name'].str.contains('Prof '))] 
df_staff
# IMPORTANT: Make sure you include a whitespace in "CA "" and "TA "" so that people with those
# #          letters in their name aren't included.  Whitespace matters! :)
# Out:
#               Name   Section  Are you a "Type A" or "Type B" personality?  \
# 0       Prof Karle       AL1        Type B (patient, flexible, laid-back)
# 1        Prof Wade       AL1  Type A (ambitious, competitive, aggressive)
# 5         TA Faaez  AYB, AYC        Type B (patient, flexible, laid-back)
# 23      CA Jackson       AYM  Type A (ambitious, competitive, aggressive)
# 24       CA Vikram       AYB  Type A (ambitious, competitive, aggressive)
# 31         CA Linh       AYP        Type B (patient, flexible, laid-back)
# 42         CA Soph       AYI  Type A (ambitious, competitive, aggressive)
# 65          CA Xin       AYM        Type B (patient, flexible, laid-back)
# 67         CA Neil       AYI  Type A (ambitious, competitive, aggressive)
# 72         CA Jake       AYQ  Type A (ambitious, competitive, aggressive)
# 73   TA Evangelos   AYE, AYI        Type B (patient, flexible, laid-back)
# 98          CA Mia       AYK        Type B (patient, flexible, laid-back)
# 107        CA Evan       AYO        Type B (patient, flexible, laid-back)
# 146     CA Jessica       AYA        Type B (patient, flexible, laid-back)
# 150       CA Emily       AYC        Type B (patient, flexible, laid-back)
# 157         CA Ram       AYP        Type B (patient, flexible, laid-back)
# 179      CA Angela  AYD, AYE        Type B (patient, flexible, laid-back)
# 183         TA Kim       AYK  Type A (ambitious, competitive, aggressive)
# 208      TA Trisha  AYP, AYM  Type A (ambitious, competitive, aggressive)
# 260      CA Eliana       AYO        Type B (patient, flexible, laid-back)
# 267        CA Sony  AYF, AYA        Type B (patient, flexible, laid-back)
# 268         CA Ana       AYB  Type A (ambitious, competitive, aggressive)
# 275      CA Alyssa       AYQ  Type A (ambitious, competitive, aggressive)
# 293      CA Anagha       AYE        Type B (patient, flexible, laid-back)
# 296       CA Talia       AYC  Type A (ambitious, competitive, aggressive)
# 312        TA Urvi  AYD, AYF  Type A (ambitious, competitive, aggressive)
# 348      CA Eeshan       AYD  Type A (ambitious, competitive, aggressive)
# 360     CA Kaitlyn       AYI  Type A (ambitious, competitive, aggressive)
# 361     CA Shannon       AYF  Type A (ambitious, competitive, aggressive)
# 366         CA Jai       AYK        Type B (patient, flexible, laid-back)
# 372      TA Yiming  AYO, AYQ  Type A (ambitious, competitive, aggressive)
#
#     Are you a morning person? Are you an international student?  \
# 0                          No                                No
# 1                          No                                No
# 5                         Yes                               Yes
# 23                         No                                No
# 24                         No                                No
# 31                         No                                No
# 42                        Yes                                No
# 65                        Yes                               Yes
# 67                         No                                No
# 72                         No                                No
# 73                        Yes                               Yes
# 98                         No                                No
# 107                        No                                No
# 146                        No                                No
# 150                       Yes                                No
# 157                       Yes                               Yes
# 179                        No                                No
# 183                        No                               Yes
# 208                       Yes                               Yes
# 260                        No                                No
# 267                       Yes                                No
# 268                       Yes                                No
# 275                       Yes                                No
# 293                        No                                No
# 296                        No                                No
# 312                        No                               Yes
# 348                       Yes                                No
# 360                        No                                No
# 361                        No                                No
# 366                        No                                No
# 372                        No                               Yes
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 0                       No                                 No
# 1                       No                                 No
# 5                       No                                 No
# 23                     NaN                                Yes
# 24                      No                                Yes
# 31                      No                                Yes
# 42                      No                                Yes
# 65                      No                                 No
# 67                      No                                 No
# 72                      No                                Yes
# 73                      No                                 No
# 98                      No                                Yes
# 107                     No                                Yes
# 146                    Yes                                 No
# 150                     No                                Yes
# 157                    Yes                                 No
# 179                     No                                Yes
# 183                    Yes                                 No
# 208                     No                                 No
# 260                     No                                Yes
# 267                     No                                 No
# 268                     No                                Yes
# 275                     No                                Yes
# 293                     No                                Yes
# 296                     No                                Yes
# 312                     No                                 No
# 348                     No                                Yes
# 360                     No                                Yes
# 361                     No                                Yes
# 366                     No                                 No
# 372                    Yes                                 No
#
#     Do you consider your home to be in the United States or Abroad?  \
# 0                                        United States
# 1                                        United States
# 5                                               Abroad
# 23                                       United States
# 24                                       United States
# 31                                       United States
# 42                                       United States
# 65                                              Abroad
# 67                                       United States
# 72                                       United States
# 73                                       United States
# 98                                       United States
# 107                                      United States
# 146                                      United States
# 150                                      United States
# 157                                             Abroad
# 179                                      United States
# 183                                             Abroad
# 208                                             Abroad
# 260                                      United States
# 267                                      United States
# 268                                      United States
# 275                                      United States
# 293                                             Abroad
# 296                                      United States
# 312                                             Abroad
# 348                                      United States
# 360                                      United States
# 361                                      United States
# 366                                      United States
# 372                                             Abroad
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 0                            In-State            Yes  ...
# 1                            In-State             No  ...
# 5                        Out-of-State             No  ...
# 23                           In-State            Yes  ...
# 24                           In-State            Yes  ...
# 31                           In-State            Yes  ...
# 42                           In-State            Yes  ...
# 65                       Out-of-State             No  ...
# 67                       Out-of-State            Yes  ...
# 72                           In-State            Yes  ...
# 73                       Out-of-State             No  ...
# 98                           In-State            Yes  ...
# 107                          In-State            Yes  ...
# 146                      Out-of-State            Yes  ...
# 150                          In-State            Yes  ...
# 157                      Out-of-State            Yes  ...
# 179                          In-State            Yes  ...
# 183                          In-State            Yes  ...
# 208                      Out-of-State            Yes  ...
# 260                          In-State            Yes  ...
# 267                          In-State            Yes  ...
# 268                          In-State            Yes  ...
# 275                          In-State             No  ...
# 293                          In-State             No  ...
# 296                          In-State            Yes  ...
# 312                      Out-of-State            Yes  ...
# 348                          In-State             No  ...
# 360                          In-State            Yes  ...
# 361                          In-State             No  ...
# 366                      Out-of-State            Yes  ...
# 372                          In-State             No  ...
#
#     What do you think is the hardest college major?  \
# 0                                  Computer Science
# 1                                                CS
# 5                                       Mathematics
# 23                              Nuclear Engineering
# 24                                   Communications
# 31                                              NaN
# 42                                Special Education
# 65                                               CS
# 67                             Computer Engineering
# 72                                               CS
# 73                                      Mathematics
# 98                                          Physics
# 107                                 [X] Engineering
# 146                                             ECE
# 150                           Aerospace Engineering
# 157                                    Mathematics
# 179                                   ?? Subjective
# 183                                         Physics
# 208                                              CS
# 260                                         Physics
# 267                                             Ece
# 268                                Computer Science
# 275                                             mcb
# 293                                       Chemistry
# 296                          Depends on the person
# 312                                         Physics
# 348                                             ECE
# 360                         Biochemical engineering
# 361                                             ECE
# 366                                             ECE
# 372                                     Programming
#
#     What genre of music do you listen to?  \
# 0                                     pop
# 1                                     Pop
# 5                                     Pop
# 23                                  Metal
# 24                                    Rap
# 31                                    pop
# 42                               Pop punk
# 65                                country
# 67                                  K-POP
# 72                                    Rap
# 73                             Rock music
# 98                                    Pop
# 107         Japanese Rock, Jazz Rock, EDM
# 146                                 Indie
# 150                           Alternative
# 157                                 K-Pop
# 179                                   Pop
# 183                                   BGM
# 208                       Rabindrasangeet
# 260                                   Pop
# 267                                 Indie
# 268                                   Rap
# 275                                   pop
# 293                                   Pop
# 296                          Classic Rock
# 312                                 Latin
# 348                             Bollywood
# 360                                   pop
# 361                           Alternative
# 366                                 House
# 372                             Pop music
#
#     What is the best boba place in Urbana-Champaign?  \
# 0                                              LaTea
# 1                                               IDK?
# 5                                        Kung Fu Tea
# 23                                           Teamoji
# 24                                           Teamoji
# 31                                             Tenko
# 42                                         Tenko Tea
# 65                                          not sure
# 67                                           Teamoji
# 72                                    Never had boba
# 73                                      I don't know
# 98                                       Kung Fu Tea
# 107                                              KFT
# 146                                            Tenko
# 150                                          Teamoji
# 157                                          Teamoji
# 179                                      Kung Fu Tea
# 183                                              NaN
# 208                                              NaN
# 260                                        Tenko Tea
# 267                                      Kung fu tea
# 268                                              NaN
# 275                                      kung fu tea
# 293                                      Tiger Sugar
# 296                                              NaN
# 312                                          No idea
# 348                                      Kung Fu Tea
# 360                                            Latea
# 361                                      Kung Fu Tea
# 366                                           Tenko?
# 372                                          No idea
#
#     What is your favorite color? What is your favorite food?  \
# 0                           pink                       Tacos
# 1                         Purple                         BBQ
# 5                            Red                       Ramen
# 23                          Gray                     Lasanga
# 24                        Purple               Fried Chicken
# 31                          blue                         NaN
# 42                           Red                        Crab
# 65                          Pink                      potato
# 67                          Teal                       Ramen
# 72                        Orange                     Popcorn
# 73                          Grey                       Pasta
# 98                          Pink              Mac and Cheese
# 107     hsla(280, 75%, 50%, 0.9)                       Pasta
# 146                   Periwinkle                       Tacos
# 150                       purple                   Ice Cream
# 157                         Blue                       Ramen
# 179                        Green                     Noodles
# 183                         blue                     chicken
# 208                          Red                        Coke
# 260                         Blue                        Rice
# 267                       Purple                       Momos
# 268                         Pink                      Yogurt
# 275                       purple                       sushi
# 293                         Blue        Extra Dark Chocolate
# 296                          Red                   Smoothies
# 312                        White                        Dosa
# 348                        Black                       Ramen
# 360                         blue                       Sushi
# 361                       Purple                       Pasta
# 366                     Cerulean                     Lobster
# 372                       Purple                        Beef
#
#     What is your favorite music artist?   What is your favorite TV show?  \
# 0                          Taylor Swift      How to Get Away with Murder
# 1                          Taylor Swift                              NaN
# 5                            The Weeknd              House of the Dragon
# 23                         Les Claypool                     Breaking Bad
# 24                                Drake                        Community
# 31                                 JVKE                              NaN
# 42                           Waterparks                 My Cat From Hell
# 65                             Wang Fei                  Stranger Things
# 67                                Twice                       The Office
# 72                            Baby Keem                      Brooklyn 99
# 73                          Hilary Hahn                             Dark
# 98                         Taylor Swift                         New Girl
# 107                 Currently, Illenium                     Breaking Bad
# 146                      The Happy Fits  Fullmetal Alchemist:Brotherhood
# 150                      Lizzy McAlpine                    Parks and Rec
# 157                               TWICE           STAT 385 video lessons
# 179                         Still Woozy                   The Good Place
# 183                                 NaN                              NaN
# 208                              Tagore                          Friends
# 260                        Taylor Swift        Avatar the Last Airbender
# 267                       weston estate                 Jane the virgin
# 268                        Radical Face                            House
# 275                       one direction                     spy x family
# 293                        Harry Styles                  Stranger Things
# 296                       Fleetwood Mac                            Elite
# 312                         The Weekend                       The Office
# 348                              Pritam                       The Office
# 360                                BTOB                         Dateline
# 361                         Beach House                   Nathan for You
# 366                       Martin Garrix                     Prison Break
# 372                            Dao Lang                             News
#
#     What's your favorite social media app?  \
# 0                                Instagram
# 1                                  YouTube
# 5                                Instagram
# 23                                  Reddit
# 24                                 Twitter
# 31                                  TikTok
# 42                                  TikTok
# 65                                  wechat
# 67                               Instagram
# 72                                  TikTok
# 73                              Instagram
# 98                               Instagram
# 107                                Twitter
# 146                              Instagram
# 150                              Instagram
# 157                                Discord
# 179                                    NaN
# 183                                    NaN
# 208                               facebook
# 260                              Instagram
# 267                                Twitter
# 268                              Instagram
# 275                                twitter
# 293                              Instagram
# 296                                 Reddit
# 312                              Instagram
# 348                                YouTube
# 360                              Instagram
# 361                                Twitter
# 366                                 Reddit
# 372                                 WeChat
#
#     Which European country would you like to visit? Similarity Score
# 0                                             Italy                9
# 1                                             Spain                2
# 5                                             Paris                6
# 23                                          Germany                7
# 24                                      Swizterland                3
# 31                                           France                4
# 42                                          Croatia                7
# 65                                            Paris                5
# 67                                      Switzerland                7
# 72                                          Germany                5
# 73                                          Denmark                9
# 98                                           France                7
# 107                                     Switzerland                8
# 146                                     Switzerland                7
# 150                                           Spain                4
# 157                                     Switzerland                5
# 179                                         Austria                7
# 183                                         Croatia                5
# 208                                             NaN                2
# 260                                          Greece                5
# 267                                     Netherlands                6
# 268                                         Romania                5
# 275                                           italy                6
# 293                                           Spain                7
# 296                                           Italy                6
# 312                                          France                8
# 348                                          Madrid                3
# 360                                         Finland                6
# 361                                     Switzerland                6
# 366                                          Greece                7
# 372                                          Greece                4
#
# [31 rows x 92 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_staff' in vars()), "Your DataFrame of course staff should be named 'df_staff'."
assert(len(df_staff) == 31), "Check you've added all the course staff correctly."
assert(len(df_staff.columns.to_list()) == 92), "You should have all of the questions columns and the Similarity Score column in df_staff." 

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.4: Course Staff Twin!
#
# Now that we have the course staff responses in `df_staff`, find your course staff twin (the staff member who has the **highest Similarity Score** to you)

# %%
df_staff.nlargest(11, "Similarity Score")
# Out:
#               Name   Section  Are you a "Type A" or "Type B" personality?  \
# 0       Prof Karle       AL1        Type B (patient, flexible, laid-back)
# 73   TA Evangelos   AYE, AYI        Type B (patient, flexible, laid-back)
# 107        CA Evan       AYO        Type B (patient, flexible, laid-back)
# 312        TA Urvi  AYD, AYF  Type A (ambitious, competitive, aggressive)
# 23      CA Jackson       AYM  Type A (ambitious, competitive, aggressive)
# 42         CA Soph       AYI  Type A (ambitious, competitive, aggressive)
# 67         CA Neil       AYI  Type A (ambitious, competitive, aggressive)
# 98          CA Mia       AYK        Type B (patient, flexible, laid-back)
# 146     CA Jessica       AYA        Type B (patient, flexible, laid-back)
# 179      CA Angela  AYD, AYE        Type B (patient, flexible, laid-back)
# 293      CA Anagha       AYE        Type B (patient, flexible, laid-back)
#
#     Are you a morning person? Are you an international student?  \
# 0                          No                                No
# 73                        Yes                               Yes
# 107                        No                                No
# 312                        No                               Yes
# 23                         No                                No
# 42                        Yes                                No
# 67                         No                                No
# 98                         No                                No
# 146                        No                                No
# 179                        No                                No
# 293                        No                                No
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 0                       No                                 No
# 73                      No                                 No
# 107                     No                                Yes
# 312                     No                                 No
# 23                     NaN                                Yes
# 42                      No                                Yes
# 67                      No                                 No
# 98                      No                                Yes
# 146                    Yes                                 No
# 179                     No                                Yes
# 293                     No                                Yes
#
#     Do you consider your home to be in the United States or Abroad?  \
# 0                                        United States
# 73                                       United States
# 107                                      United States
# 312                                             Abroad
# 23                                       United States
# 42                                       United States
# 67                                       United States
# 98                                       United States
# 146                                      United States
# 179                                      United States
# 293                                             Abroad
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 0                            In-State            Yes  ...
# 73                       Out-of-State             No  ...
# 107                          In-State            Yes  ...
# 312                      Out-of-State            Yes  ...
# 23                           In-State            Yes  ...
# 42                           In-State            Yes  ...
# 67                       Out-of-State            Yes  ...
# 98                           In-State            Yes  ...
# 146                      Out-of-State            Yes  ...
# 179                          In-State            Yes  ...
# 293                          In-State             No  ...
#
#     What do you think is the hardest college major?  \
# 0                                  Computer Science
# 73                                      Mathematics
# 107                                 [X] Engineering
# 312                                         Physics
# 23                              Nuclear Engineering
# 42                                Special Education
# 67                             Computer Engineering
# 98                                          Physics
# 146                                             ECE
# 179                                   ?? Subjective
# 293                                       Chemistry
#
#     What genre of music do you listen to?  \
# 0                                     pop
# 73                             Rock music
# 107         Japanese Rock, Jazz Rock, EDM
# 312                                 Latin
# 23                                  Metal
# 42                               Pop punk
# 67                                  K-POP
# 98                                    Pop
# 146                                 Indie
# 179                                   Pop
# 293                                   Pop
#
#     What is the best boba place in Urbana-Champaign?  \
# 0                                              LaTea
# 73                                      I don't know
# 107                                              KFT
# 312                                          No idea
# 23                                           Teamoji
# 42                                         Tenko Tea
# 67                                           Teamoji
# 98                                       Kung Fu Tea
# 146                                            Tenko
# 179                                      Kung Fu Tea
# 293                                      Tiger Sugar
#
#     What is your favorite color? What is your favorite food?  \
# 0                           pink                       Tacos
# 73                          Grey                       Pasta
# 107     hsla(280, 75%, 50%, 0.9)                       Pasta
# 312                        White                        Dosa
# 23                          Gray                     Lasanga
# 42                           Red                        Crab
# 67                          Teal                       Ramen
# 98                          Pink              Mac and Cheese
# 146                   Periwinkle                       Tacos
# 179                        Green                     Noodles
# 293                         Blue        Extra Dark Chocolate
#
#     What is your favorite music artist?   What is your favorite TV show?  \
# 0                          Taylor Swift      How to Get Away with Murder
# 73                          Hilary Hahn                             Dark
# 107                 Currently, Illenium                     Breaking Bad
# 312                         The Weekend                       The Office
# 23                         Les Claypool                     Breaking Bad
# 42                           Waterparks                 My Cat From Hell
# 67                                Twice                       The Office
# 98                         Taylor Swift                         New Girl
# 146                      The Happy Fits  Fullmetal Alchemist:Brotherhood
# 179                         Still Woozy                   The Good Place
# 293                        Harry Styles                  Stranger Things
#
#     What's your favorite social media app?  \
# 0                                Instagram
# 73                              Instagram
# 107                                Twitter
# 312                              Instagram
# 23                                  Reddit
# 42                                  TikTok
# 67                               Instagram
# 98                               Instagram
# 146                              Instagram
# 179                                    NaN
# 293                              Instagram
#
#     Which European country would you like to visit? Similarity Score
# 0                                             Italy                9
# 73                                          Denmark                9
# 107                                     Switzerland                8
# 312                                          France                8
# 23                                          Germany                7
# 42                                          Croatia                7
# 67                                      Switzerland                7
# 98                                           France                7
# 146                                     Switzerland                7
# 179                                         Austria                7
# 293                                           Spain                7
#
# [11 rows x 92 columns]

# %% [markdown]
# ### Analysis: Final Reflection
#
# **Q3: Do you think our method of finding similar people is effective? Why or why not? What could improve it?**

# %% [markdown]
# *(✏️ I think it is effective to a certain point. I would add all questions so that I can find my true twin and not just use 12 questions out of 100 ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
